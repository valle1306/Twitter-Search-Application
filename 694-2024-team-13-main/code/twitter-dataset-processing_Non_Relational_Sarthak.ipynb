# %%
pip install pymongo
# Out:
# Requirement already satisfied: pymongo in /Users/alvinalex/anaconda3/lib/python3.11/site-packages (4.6.3)
# Requirement already satisfied: dnspython<3.0.0,>=1.16.0 in /Users/alvinalex/anaconda3/lib/python3.11/site-packages (from pymongo) (2.6.1)
# Note: you may need to restart the kernel to use updated packages.

# %%
import json
import pprint
from datetime import datetime
from pymongo import MongoClient

# %%
#MONGODB_URL="mongodb+srv://ss4767:JadonSancho%407@cluster0.r6mgzuu.mongodb.net/?retryWrites=true&w=majority&appName=Cluster0"
MONGODB_URL="mongodb://localhost:27017"
client=MongoClient(MONGODB_URL)
tweets_collection= client.dbms_project.tweets

# %%
#Clear the entire collection
tweets_collection.delete_many({})
print("Collection cleared. Ready to start anew.")
# Out:
# Collection cleared. Ready to start anew.

# %%
#so that duplicate documents dont get inserted(raises an error)
tweets_collection.create_index("tweet_id", unique=True)
# Out:
# 'tweet_id_1'

# %%
#we are reading the contents of the original tweet if the tweet is retweeted 
#for access to extended tweeet if available
def get_tweet_text(data):
    # Check if the tweet is a retweet based on the text content
    if data['text'].startswith('RT'):
        # Retrieve the original tweet's data from the retweeted_status, if available
        retweet = data.get('retweeted_status', {})
        if 'extended_tweet' in retweet:
            # Use full_text from extended_tweet if available
            return retweet['extended_tweet']['full_text']
        else:
            # Use text from retweeted_status if extended_tweet is not available
            return retweet.get('text', data['text'])
    else:
        # For a non-retweet, check if it's an extended tweet
        if 'extended_tweet' in data:
            # Use full_text from extended_tweet if available
            return data['extended_tweet']['full_text']
        else:
            # Use standard text field if it's not an extended tweet
            return data['text']

# %%
def get_hashtags(data):
    # Check if the tweet is a retweet and extract hashtags accordingly
    if data['text'].startswith('RT') and 'retweeted_status' in data:
        retweet = data['retweeted_status']
        hashtags_list = retweet.get('extended_tweet', {}).get('entities', {}).get('hashtags', retweet.get('entities', {}).get('hashtags', []))
    else:
        hashtags_list = data.get('extended_tweet', {}).get('entities', {}).get('hashtags', data.get('entities', {}).get('hashtags', []))
    return [hashtag['text'] for hashtag in hashtags_list]

# %%
def read_and_insert(file_name):
    with open(file_name, 'r') as file:
        for line in file:
            try:
                data = json.loads(line)
                if tweets_collection.count_documents({"tweet_id": data["id"]}) == 0:
                    tweet_text = get_tweet_text(data)
                    hashtags = get_hashtags(data)

                    tweet_document = {
                        "tweet_id": data["id"],
                        "text": tweet_text,
                        "hashtags": hashtags,
                        "user": {
                            "user_id": data['user']['id'],
                            "name": data['user']['name'],
                            "screen_name": data['user']['screen_name']
                        },
                        "created_at": parse_date(data['created_at'])
                    }

                    tweets_collection.insert_one(tweet_document)
            except (json.JSONDecodeError, KeyError):
                continue  # Skip invalid or incomplete lines

# %%
def parse_date(date_str):
    return datetime.strptime(date_str, '%a %b %d %H:%M:%S %z %Y')

# File paths
file_1 = '../data/corona-out-2'
file_2 = '../data/corona-out-3'

# Process each file
read_and_insert(file_1)
read_and_insert(file_2)

print("Documents inserted")
# Out:
# Documents inserted

# %%
tweets_collection.create_index([("text", "text")])
tweets_collection.create_index([("hashtags", 1)])
tweets_collection.create_index([("user.screen_name", 1)])
# Out:
# 'user.screen_name_1'

# %%
query = "holiday"
results = tweets_collection.find({"$text": {"$search": query}})
for result in results:
    print(result)
# Out:
# {'_id': ObjectId('66256f62ecffc84c2647253d'), 'tweet_id': 1254027543868510208, 'text': 'Corona declared 2020 a public holiday.', 'hashtags': [], 'user': {'user_id': 198743397, 'name': 'Wallflower (@ 🏡)', 'screen_name': 'TheAaronAlasa'}, 'created_at': datetime.datetime(2020, 4, 25, 12, 40, 39)}
# {'_id': ObjectId('66256f6eecffc84c2647f017'), 'tweet_id': 1254046481507422210, 'text': '"Corona\'s holiday homework" is gotta do now, but I\'m not motivated', 'hashtags': [], 'user': {'user_id': 1252284793066143744, 'name': 'sii', 'screen_name': 'sii1313131313E'}, 'created_at': datetime.datetime(2020, 4, 25, 13, 55, 54)}
# {'_id': ObjectId('66256f66ecffc84c2647714a'), 'tweet_id': 1254034781517557760, 'text': 'Looks like we r off to Poland for our summer holidays @b_wisey82', 'hashtags': [], 'user': {'user_id': 105126289, 'name': 'Paul Ley', 'screen_name': 'paul_ley'}, 'created_at': datetime.datetime(2020, 4, 25, 13, 9, 25)}
# {'_id': ObjectId('66256f5eecffc84c2646e75d'), 'tweet_id': 1249407792391303169, 'text': 'Apparently Corona virus went on Easter holiday in naij🦋🙂', 'hashtags': [], 'user': {'user_id': 3362458251, 'name': '𓃗☿', 'screen_name': 'asipoflynn'}, 'created_at': datetime.datetime(2020, 4, 12, 18, 43, 25)}
# {'_id': ObjectId('66256f5becffc84c2646ba6b'), 'tweet_id': 1249404661339230208, 'text': 'Corona got me forgetting all about holidays where tf Easter come from ?', 'hashtags': [], 'user': {'user_id': 522796201, 'name': 'JWOO ‼️', 'screen_name': 'Its_YoungJayy'}, 'created_at': datetime.datetime(2020, 4, 12, 18, 30, 58)}
# {'_id': ObjectId('66256f70ecffc84c26481478'), 'tweet_id': 1254049824795746304, 'text': 'There should be a national holiday on the day Nigeria will be declared Corona free.', 'hashtags': [], 'user': {'user_id': 150662905, 'name': 'Manny 🌚', 'screen_name': 'mannylams'}, 'created_at': datetime.datetime(2020, 4, 25, 14, 9, 12)}
# {'_id': ObjectId('66256f6aecffc84c2647b2f1'), 'tweet_id': 1254040837656371200, 'text': 'There should be a national holiday on the day Nigeria will be declared Corona free.', 'hashtags': [], 'user': {'user_id': 950016451385192448, 'name': 'Crème de la crème', 'screen_name': 'adenike_21'}, 'created_at': datetime.datetime(2020, 4, 25, 13, 33, 29)}
# {'_id': ObjectId('66256f63ecffc84c26473f32'), 'tweet_id': 1254030058576064514, 'text': 'Fuck corona I really thought I was gonna go holiday every month', 'hashtags': [], 'user': {'user_id': 1165085822233776128, 'name': 't huncho', 'screen_name': 'Erro_100'}, 'created_at': datetime.datetime(2020, 4, 25, 12, 50, 39)}
# {'_id': ObjectId('66256f70ecffc84c2648125c'), 'tweet_id': 1254049616699576322, 'text': 'What´s about our nudist-holidays in times of corona ?, read more here: https://t.co/tS1dAOBPog', 'hashtags': [], 'user': {'user_id': 707639674202939392, 'name': 'Yalnız Adam', 'screen_name': 'sporyapmak'}, 'created_at': datetime.datetime(2020, 4, 25, 14, 8, 22)}
# {'_id': ObjectId('66256f69ecffc84c2647a583'), 'tweet_id': 1254039607756423174, 'text': '2 years ago I booked my first holiday, corona had to co** block this year', 'hashtags': [], 'user': {'user_id': 411698734, 'name': 'Ray', 'screen_name': 'Rayhxn98'}, 'created_at': datetime.datetime(2020, 4, 25, 13, 28, 36)}
# {'_id': ObjectId('66256f5decffc84c2646e155'), 'tweet_id': 1249407350278107136, 'text': 'I’m lucky I was able to go on holiday just before this corona shit started getting worse', 'hashtags': [], 'user': {'user_id': 700805477362438144, 'name': 'K A R I N A🌸', 'screen_name': 'karina99xox'}, 'created_at': datetime.datetime(2020, 4, 12, 18, 41, 39)}
# {'_id': ObjectId('66256f5decffc84c2646dcdf'), 'tweet_id': 1249407049433321473, 'text': 'my favorite freaking holiday today and it’s ruined by corona and tornados. 2020 is by far the worst year ever', 'hashtags': [], 'user': {'user_id': 3303784586, 'name': 'B', 'screen_name': 'baytibbs1'}, 'created_at': datetime.datetime(2020, 4, 12, 18, 40, 28)}
# {'_id': ObjectId('66256f6decffc84c2647dcd1'), 'tweet_id': 1254044752368017410, 'text': 'https://t.co/cojHZqhGor #traveler #hotel #visitasia #holidays #hotels #bookings #asia #traveltips #travelling #touring', 'hashtags': ['traveler', 'hotel', 'visitasia', 'holidays', 'hotels', 'bookings', 'asia', 'traveltips', 'travelling', 'touring'], 'user': {'user_id': 1006434293365837826, 'name': 'Melissa Mendoza', 'screen_name': 'Melissa48538992'}, 'created_at': datetime.datetime(2020, 4, 25, 13, 49, 2)}
# {'_id': ObjectId('66256f68ecffc84c26479873'), 'tweet_id': 1254038426149695489, 'text': 'Dear corona,\nYou better be done with your shit by July cuz I have my summer holidays to attend to. I hope I’ve made myself crystal clear bitch.', 'hashtags': [], 'user': {'user_id': 1184991044435353602, 'name': 'khushi :))', 'screen_name': '_itskhushi'}, 'created_at': datetime.datetime(2020, 4, 25, 13, 23, 54)}
# {'_id': ObjectId('66256f76ecffc84c264872fc'), 'tweet_id': 1254058236707082240, 'text': "#Italy's Liberation Day (Italian: Festa della liberazione), is a national Italian holiday commemorating the end of Nazi occupation during World War II and the victory of the #Resistance in 🇮🇹.", 'hashtags': ['Italy', 'Resistance'], 'user': {'user_id': 393082374, 'name': 'Alessandro AE Anzani', 'screen_name': 'AleAeAnzani'}, 'created_at': datetime.datetime(2020, 4, 25, 14, 42, 37)}
# {'_id': ObjectId('66256f6decffc84c2647e551'), 'tweet_id': 1254045526179414023, 'text': "XL bottle of corona... bikini on... factor 2 oil on with that holiday coconut smell... @DefectedRecords blasting out... if I close my eyes I swear I'm at Jet apartments #ifyouknowyouknow #ibiza #jetjetjet", 'hashtags': ['ifyouknowyouknow', 'ibiza', 'jetjetjet'], 'user': {'user_id': 49433775, 'name': 'Gemma Larkin', 'screen_name': 'gemgeml'}, 'created_at': datetime.datetime(2020, 4, 25, 13, 52, 7)}
# {'_id': ObjectId('66256f64ecffc84c264754c4'), 'tweet_id': 1254032109485936641, 'text': "A government which only cares about the rich. Please also seek to know the misery being faced by millions of stranded workers across the country, even as the rich enjoy 'holidays'.\n#EndSanctionsSaveLives \n#WorkersLeftToDie", 'hashtags': ['EndSanctionsSaveLives', 'WorkersLeftToDie'], 'user': {'user_id': 1246774367444328450, 'name': 'प्रीति ज्योति', 'screen_name': 'AfdU1Y7JiNN2OTu'}, 'created_at': datetime.datetime(2020, 4, 25, 12, 58, 48)}
# {'_id': ObjectId('66256f71ecffc84c2648273a'), 'tweet_id': 1254051533924323329, 'text': 'Perish the though thst  PM would miss 6 cobra meetings, be in hiding, holidaying in Jan Feb, while country flooded and a deadly virus spread, I mean Corona, Cummings was already established', 'hashtags': [], 'user': {'user_id': 309908788, 'name': 'Mark Stacey', 'screen_name': 'VintiquesMark'}, 'created_at': datetime.datetime(2020, 4, 25, 14, 15, 59)}
# {'_id': ObjectId('66256f6cecffc84c2647d77a'), 'tweet_id': 1254044248858640385, 'text': '@LCPS07 Zachary &amp; Reuben is enjoying a "lockdown holiday" in our garden in the "Corona Cabin". Lunch cooked outside too over open Fire. They built a Marble run too!! https://t.co/BIwRxgfPKF', 'hashtags': [], 'user': {'user_id': 1253221911842217985, 'name': 'Hibaska', 'screen_name': 'Hibaska1'}, 'created_at': datetime.datetime(2020, 4, 25, 13, 47, 2)}
# {'_id': ObjectId('66256f6aecffc84c2647adb0'), 'tweet_id': 1254040344695648256, 'text': 'THE CORONA VIRUS IS AN AWAKENING🌻DID WE EVER THINK THAT WE COULD GIVE MORE FREE DAYS OF NOT BEING ON THE HOLIDAY CALENDAR🌻PLANNED FLEXIBLE TIME TO THINK🌻SUPERVISOR SAYS EVERYONE TAKE THE DAY OFF🌻LEAVE 2 PAID or WHATEVER HOLD THE FORT🌻', 'hashtags': [], 'user': {'user_id': 36486327, 'name': 'Sheryl Fisher', 'screen_name': 'shryl'}, 'created_at': datetime.datetime(2020, 4, 25, 13, 31, 31)}
# {'_id': ObjectId('66256f67ecffc84c264784a7'), 'tweet_id': 1254036613719621638, 'text': 'Supposed to of flew out to spain at 6am this morning. Would of picked up our car, blasting the holiday tunes out, driving on the wrong side of the road to our villa, and chilling in the sun eating lays crisps by now. But corona had other ideas.', 'hashtags': [], 'user': {'user_id': 284658716, 'name': 'Rach.', 'screen_name': 'RaaaachelTay'}, 'created_at': datetime.datetime(2020, 4, 25, 13, 16, 42)}
# {'_id': ObjectId('66256f5decffc84c2646e046'), 'tweet_id': 1249407284444368898, 'text': 'TL sleep? \n\nWell if you see this do not let Corona distract you from acknowledging today’s holiday. You don’t have to be perfect to seek God. He already died for you and me. You might as well invite him into your presence. Talk to him 🥰', 'hashtags': [], 'user': {'user_id': 1369464366, 'name': 'Speakingofozioma🌹🥂', 'screen_name': 'speakingofozi'}, 'created_at': datetime.datetime(2020, 4, 12, 18, 41, 24)}
# {'_id': ObjectId('66256f74ecffc84c2648540c'), 'tweet_id': 1254055591871426563, 'text': 'The smell of these trees remind me of summer holidays, mid July in France. It is April in the Netherlands though 🤔. Not only the days look alike now, but the seasons are messed up as well.  Corona mash up. https://t.co/Kk524RF1TY', 'hashtags': [], 'user': {'user_id': 4726140143, 'name': 'Mark 🇪🇺', 'screen_name': 'markhugfanginn'}, 'created_at': datetime.datetime(2020, 4, 25, 14, 32, 6)}
# {'_id': ObjectId('66256f62ecffc84c26472d5f'), 'tweet_id': 1254028340824080384, 'text': "When the Corona Virus finally exhausts itself and the danger is over, let's do something good for our country,\nLet's spend our holidays in England, eat in local restaurants, buy British products, buy local meats and veggies and support local businesses #COVID2019", 'hashtags': ['COVID2019'], 'user': {'user_id': 257488312, 'name': 'David and Lee', 'screen_name': 'thought_weavers'}, 'created_at': datetime.datetime(2020, 4, 25, 12, 43, 49)}
# {'_id': ObjectId('66256f5fecffc84c2646f3c1'), 'tweet_id': 1249408703020675073, 'text': 'Holiday Special: Trump Supporter of the Day.\n\nUnlike most Trump Supporters, this one is willing to reveal what they really think.\n\nLike most Trump Supporters, the most batshit crazy conspiracy theories blow through her brain like a hurricane of BS.', 'hashtags': [], 'user': {'user_id': 127258729, 'name': 'mjb', 'screen_name': 'mjb0007'}, 'created_at': datetime.datetime(2020, 4, 12, 18, 47, 2)}
# {'_id': ObjectId('66256f77ecffc84c26488256'), 'tweet_id': 1254059564602810368, 'text': '@iavor20011 @SMF_Frieza we should get a chapter 978 last week if not because of the corona situation, and we should got the chapter 979 this week. \n\nAnd then, there is golden week (holiday week) in the Japan next week. Thats why we dont get chapter for next week.', 'hashtags': [], 'user': {'user_id': 1245684564, 'name': 'Hyakujuu No Kaido', 'screen_name': 'hyakujukaido'}, 'created_at': datetime.datetime(2020, 4, 25, 14, 47, 54)}
# {'_id': ObjectId('66256f5becffc84c2646b1f1'), 'tweet_id': 1249404036111089672, 'text': "Alot of businesses were looking forward to the Easter sales. A better part of their 2nd quarter revenue depend on the sales from this period.\n\nBut Corona looked at them and said 'hold my beer'.\n\nWe'll need another 'Easter' when this is over. A public holiday and a sunday service.", 'hashtags': [], 'user': {'user_id': 536034920, 'name': 'Akinkunmi Abeeb', 'screen_name': 'abelianboy'}, 'created_at': datetime.datetime(2020, 4, 12, 18, 28, 29)}
# {'_id': ObjectId('66256f6aecffc84c2647ba82'), 'tweet_id': 1254041522317729792, 'text': '25th April is Liberation Day in Italy, a public holiday commemorating the fall of Fascism and the end of the Nazi occupation which followed. Sergio Mattarella paid his respects alone at the tomb of an unknown soldier from the First World War at the deserted national monument.', 'hashtags': [], 'user': {'user_id': 848799105946177537, 'name': 'Lady Fuchsia Aurelius 🌈', 'screen_name': 'TheLadyFuchsia'}, 'created_at': datetime.datetime(2020, 4, 25, 13, 36, 12)}
# {'_id': ObjectId('66256f68ecffc84c264789b6'), 'tweet_id': 1254037079081848832, 'text': '25th April is Liberation Day in Italy, a public holiday commemorating the fall of Fascism and the end of the Nazi occupation which followed. Sergio Mattarella paid his respects alone at the tomb of an unknown soldier from the First World War at the deserted national monument.', 'hashtags': [], 'user': {'user_id': 17025180, 'name': 'Gillian McGuire', 'screen_name': 'gmcguireinrome'}, 'created_at': datetime.datetime(2020, 4, 25, 13, 18, 33)}
# {'_id': ObjectId('66256f67ecffc84c2647859b'), 'tweet_id': 1254036708036927488, 'text': '25th April is Liberation Day in Italy, a public holiday commemorating the fall of Fascism and the end of the Nazi occupation which followed. Sergio Mattarella paid his respects alone at the tomb of an unknown soldier from the First World War at the deserted national monument.', 'hashtags': [], 'user': {'user_id': 2625233435, 'name': 'Edoardo Fanfani', 'screen_name': 'EdoardoFanfani'}, 'created_at': datetime.datetime(2020, 4, 25, 13, 17, 4)}
# {'_id': ObjectId('66256f5fecffc84c2646f835'), 'tweet_id': 1254022933565054976, 'text': '25th April is Liberation Day in Italy, a public holiday commemorating the fall of Fascism and the end of the Nazi occupation which followed. Sergio Mattarella paid his respects alone at the tomb of an unknown soldier from the First World War at the deserted national monument.', 'hashtags': [], 'user': {'user_id': 134135559, 'name': 'Agnes Crawford', 'screen_name': 'understandrome'}, 'created_at': datetime.datetime(2020, 4, 25, 12, 22, 20)}
# {'_id': ObjectId('66256f5decffc84c2646d678'), 'tweet_id': 1249406592040173568, 'text': "Relieved Boris Johnson has recovered.\n\nHe has now travelled to his 2nd home to convalesce. How does that work? People are allowed to travel to 2nd homes now? Or only if you've had Corona virus? If you have no 2nd home, can you book a holiday instead? https://t.co/GQ7sW9Pbor", 'hashtags': [], 'user': {'user_id': 624993878, 'name': 'piodenteifi', 'screen_name': 'piodenteifi'}, 'created_at': datetime.datetime(2020, 4, 12, 18, 38, 39)}
# {'_id': ObjectId('66256f5decffc84c2646d23d'), 'tweet_id': 1249406302465314817, 'text': 'Cylinder delivered to a Corona positive family by owner of Comfort Bharatgas and Kasargod police. As it was holiday, proprietor carried cylinder in private vehicle and delivered with all precautions, Service with dedication @PeethambarantT @BPCLimited @dpradhanbjp @singharunbpcl https://t.co/aY3GhgSaLQ', 'hashtags': [], 'user': {'user_id': 1382431273, 'name': '@venu_bpcl', 'screen_name': 'venulogic'}, 'created_at': datetime.datetime(2020, 4, 12, 18, 37, 30)}
# {'_id': ObjectId('66256f5cecffc84c2646cd89'), 'tweet_id': 1249405977914466304, 'text': "Relieved Boris Johnson has recovered.\n\nHe has now travelled to his 2nd home to convalesce. How does that work? People are allowed to travel to 2nd homes now? Or only if you've had Corona virus? If you have no 2nd home, can you book a holiday instead? https://t.co/GQ7sW9Pbor", 'hashtags': [], 'user': {'user_id': 793043434600820736, 'name': 'Russell Bentley', 'screen_name': 'russell_runner'}, 'created_at': datetime.datetime(2020, 4, 12, 18, 36, 12)}
# {'_id': ObjectId('66256f70ecffc84c2648128a'), 'tweet_id': 1254049632545579009, 'text': 'TMI but I was supposed to go Seoul for my holidays from 10th - 21st March but my flight got cancelled due to Ms Corona. I was supposed to travel solo and my main agenda was to go cafe-hopping and take aesthetic pictures/do a vlog. Can you imagine being in a cafe', 'hashtags': [], 'user': {'user_id': 1024338385404682246, 'name': 'ClaimCompanies.com', 'screen_name': 'claimcompanies'}, 'created_at': datetime.datetime(2020, 4, 25, 14, 8, 26)}
# {'_id': ObjectId('66256f6eecffc84c2647ef4b'), 'tweet_id': 1254046404109983747, 'text': 'TMI but I was supposed to go Seoul for my holidays from 10th - 21st March but my flight got cancelled due to Ms Corona. I was supposed to travel solo and my main agenda was to go cafe-hopping and take aesthetic pictures/do a vlog. Can you imagine being in a cafe', 'hashtags': [], 'user': {'user_id': 1213843040969752578, 'name': '♕ 𝐲𝐨𝐮𝐫 𝐡𝐢𝐠𝐡𝐧𝐞𝐬𝐬, 𝒿𝑒𝑜𝓃 𝓌𝑜𝓃𝓌𝑜𝑜', 'screen_name': 'wonuhighness'}, 'created_at': datetime.datetime(2020, 4, 25, 13, 55, 36)}
# {'_id': ObjectId('66256f5cecffc84c2646c69c'), 'tweet_id': 1249405547129925632, 'text': 'When Corona Virus  is over, let’s spend our holidays in India, eat in local restaurants, buy local meats and veggies , buy clothes and shoes from indian brands and support local businesses. These businesses are going to find it very difficult to survive without our help.', 'hashtags': [], 'user': {'user_id': 164932759, 'name': 'Raj jha', 'screen_name': 'Rajjha07'}, 'created_at': datetime.datetime(2020, 4, 12, 18, 34, 29)}
# {'_id': ObjectId('66256f6fecffc84c264807be'), 'tweet_id': 1254048625782657024, 'text': '@Mulboyne The major Eikaiwas are holding pens for gap year and "working holiday" people from the Anglosphere, so that Japanese youths can also get such a visa from the UK, Australia, NZ, etc.  So here, you see, literally.  If they get corona, well, "gaijin problem" and back on the plane.', 'hashtags': [], 'user': {'user_id': 66099035, 'name': 'Rick Gundlach', 'screen_name': 'Hoofin'}, 'created_at': datetime.datetime(2020, 4, 25, 14, 4, 26)}
# {'_id': ObjectId('66256f6eecffc84c2647eea6'), 'tweet_id': 1254046353237241856, 'text': 'TMI but I was supposed to go Seoul for my holidays from 10th - 21st March but my flight got cancelled due to Ms Corona. I was supposed to travel solo and my main agenda was to go cafe-hopping and take aesthetic pictures/do a vlog. Can you imagine being in a cafe and suddenly you', 'hashtags': [], 'user': {'user_id': 1213843040969752578, 'name': '♕ 𝐲𝐨𝐮𝐫 𝐡𝐢𝐠𝐡𝐧𝐞𝐬𝐬, 𝒿𝑒𝑜𝓃 𝓌𝑜𝓃𝓌𝑜𝑜', 'screen_name': 'wonuhighness'}, 'created_at': datetime.datetime(2020, 4, 25, 13, 55, 24)}
# {'_id': ObjectId('66256f6cecffc84c2647da27'), 'tweet_id': 1254044493852147715, 'text': 'Can I give you a challenge for the coming summer when corona is over?\nThen sign up for the mission trip to Lloret de Mar!\nhttps://t.co/53yJOOlYil\n\n#evangelization #youngpeople #travel #beachmission #christian #evangelist #evangelizationtrip #holiday #mission #Jesus https://t.co/l5vY5k5N7Q', 'hashtags': ['evangelization', 'youngpeople', 'travel', 'beachmission', 'christian', 'evangelist', 'evangelizationtrip', 'holiday', 'mission', 'Jesus'], 'user': {'user_id': 2938230611, 'name': 'Beach Mission', 'screen_name': 'beachmissionorg'}, 'created_at': datetime.datetime(2020, 4, 25, 13, 48, 1)}
# {'_id': ObjectId('66256f5decffc84c2646da4d'), 'tweet_id': 1249406859926274048, 'text': "Corona virus isn't a joke! Lockdown isn't a holiday! Please just STAY THE FUCK HOME!!! My neighbour's 'healthy' brother was on a ventilator for 2 weeks and is still weak, one of my cousins is lying in a hospital bed suffering, and someone I know has just died!!! Get a Grip!!!", 'hashtags': [], 'user': {'user_id': 1175088947300618248, 'name': 'LUCY', 'screen_name': 'LUCY_the_GEMINI'}, 'created_at': datetime.datetime(2020, 4, 12, 18, 39, 42)}
# {'_id': ObjectId('66256f68ecffc84c26478e99'), 'tweet_id': 1254037532821651462, 'text': "@ReekadoBanks  please bro help me,I need your help I want to get mummy somethings and me to sustain till Corona virus holiday end please,my father is no more,I'm part of the people give my younger bro &amp;sis one in a while please help me,thanks baba https://t.co/vvXiSjhYhC", 'hashtags': [], 'user': {'user_id': 1250890797404377091, 'name': '@iamolasunkanmidon', 'screen_name': 'iamolasunkanmi2'}, 'created_at': datetime.datetime(2020, 4, 25, 13, 20, 21)}
# {'_id': ObjectId('66256f65ecffc84c26476337'), 'tweet_id': 1254033480171675648, 'text': '@KTRTRS  sir As per govt orders given there wont be rents in hyd for few days.but we employees stay in hostels vacated in march month due to corona holidays.hostel owners are demanding full fees without concession.kindly give solution for this too.helps lot of people like us', 'hashtags': [], 'user': {'user_id': 1253929072935096320, 'name': 'Gowri', 'screen_name': 'Gowri90842920'}, 'created_at': datetime.datetime(2020, 4, 25, 13, 4, 15)}
# {'_id': ObjectId('66256f65ecffc84c264759ac'), 'tweet_id': 1254032549137076226, 'text': "@toyin_abraham1 please sis help me,I need your help I want to get mummy somethings and me to sustain till Corona virus holiday end please,my father is no more,I'm part of the people give my younger bro &amp;sis one in a while please help me,thanks ma https://t.co/vvXiSjhYhC", 'hashtags': [], 'user': {'user_id': 1250890797404377091, 'name': '@iamolasunkanmidon', 'screen_name': 'iamolasunkanmi2'}, 'created_at': datetime.datetime(2020, 4, 25, 13, 0, 33)}
# {'_id': ObjectId('66256f65ecffc84c264756ea'), 'tweet_id': 1254032304059662336, 'text': "@toyin_abraham1 please sis help me,I need your help I want to get mummy somethings and me to sustain till Corona virus holiday end please,my father is no more,I'm part of the people give my younger bro &amp;sis one in a while please help me,thanks ma https://t.co/vvXiSjhYhC", 'hashtags': [], 'user': {'user_id': 1250890797404377091, 'name': '@iamolasunkanmidon', 'screen_name': 'iamolasunkanmi2'}, 'created_at': datetime.datetime(2020, 4, 25, 12, 59, 34)}
# {'_id': ObjectId('66256f72ecffc84c26482f99'), 'tweet_id': 1254052297362956289, 'text': '@KTRTRS hi https://t.co/IXY2VkwWGN per govt orders there wont be rents in hyd for few days.but we employees stay in hostels vacated in march month due to corona holidays.hostel owners are demanding full fees without concession.kindly give solution for this too.helps lot of people', 'hashtags': [], 'user': {'user_id': 1253929072935096320, 'name': 'Gowri', 'screen_name': 'Gowri90842920'}, 'created_at': datetime.datetime(2020, 4, 25, 14, 19, 1)}
# {'_id': ObjectId('66256f67ecffc84c26477b9f'), 'tweet_id': 1254035753119690753, 'text': "@toyin_abraham1 @toyin_abraham1 please sis help me,I need your help I want to get mummy somethings and me to sustain till Corona virus holiday end please,my father is no more,I'm part of the people give my younger bro &amp;sis one in a while please help me,thanks ma https://t.co/vvXiSjhYhC", 'hashtags': [], 'user': {'user_id': 1250890797404377091, 'name': '@iamolasunkanmidon', 'screen_name': 'iamolasunkanmi2'}, 'created_at': datetime.datetime(2020, 4, 25, 13, 13, 17)}
# {'_id': ObjectId('66256f65ecffc84c26475cbd'), 'tweet_id': 1254032831694532609, 'text': '@KTRTRS hi https://t.co/IXY2VkwWGN per govt orders there wont be rents in hyd for few days.but we employees stay in hostels vacated in march month due to corona holidays.hostel owners are demanding full fees without concession.kindly give solution for this too.helps lot of people', 'hashtags': [], 'user': {'user_id': 1253929072935096320, 'name': 'Gowri', 'screen_name': 'Gowri90842920'}, 'created_at': datetime.datetime(2020, 4, 25, 13, 1, 40)}
# {'_id': ObjectId('66256f5becffc84c2646b84b'), 'tweet_id': 1249404503566278657, 'text': 'So far thanks to corona I’ve had to spend the 2 year anniversary of my dads suicide and Mother’s Day alone completely in my flat (both same day this year) and now Easter holiday so I don’t wanna hear no excuses about why someone can’t follow the rules &amp; not stay they ass home 😒', 'hashtags': [], 'user': {'user_id': 294712456, 'name': 'Sophie Jackson', 'screen_name': 'Sophie_J_1990'}, 'created_at': datetime.datetime(2020, 4, 12, 18, 30, 21)}
# {'_id': ObjectId('66256f60ecffc84c26470e72'), 'tweet_id': 1254025179459579904, 'text': "Dear Corona \n\nCepat pulang nak ..\nSudah cukup nak kamu holiday keliling dunia nya :')\nTerimakasih sudah menyatukan dunia, mengingatkan manusia betapa pentingnya menjaga kesehatan..\nKami hanya ingin Ramadhan nanti bisa merasakan nikmatnya tanpa adanya #lockdown :')\n\n🌻", 'hashtags': ['lockdown'], 'user': {'user_id': 1249672487572361217, 'name': 'Kertas Usang', 'screen_name': 'AlawiyahAlvi'}, 'created_at': datetime.datetime(2020, 4, 25, 12, 31, 16)}
# {'_id': ObjectId('66256f6decffc84c2647e44b'), 'tweet_id': 1254045438451363840, 'text': "@DONJAZZY please sis help me,I need your help I want to get mummy somethings and me to sustain till Corona virus holiday end please,my father is no more,I'm part of the people give my younger bro &amp;sis one in a while please help me,thanks ma https://t.co/vvXiSjhYhC https://t.co/E9hJDCRS1s", 'hashtags': [], 'user': {'user_id': 1250890797404377091, 'name': '@iamolasunkanmidon', 'screen_name': 'iamolasunkanmi2'}, 'created_at': datetime.datetime(2020, 4, 25, 13, 51, 46)}
# {'_id': ObjectId('66256f6aecffc84c2647aef1'), 'tweet_id': 1254040476216438785, 'text': "@DONJAZZY please sis help me,I need your help I want to get mummy somethings and me to sustain till Corona virus holiday end please,my father is no more,I'm part of the people give my younger bro &amp;sis one in a while please help me,thanks ma https://t.co/vvXiSjhYhC https://t.co/E9hJDCRS1s", 'hashtags': [], 'user': {'user_id': 1250890797404377091, 'name': '@iamolasunkanmidon', 'screen_name': 'iamolasunkanmi2'}, 'created_at': datetime.datetime(2020, 4, 25, 13, 32, 3)}
# {'_id': ObjectId('66256f67ecffc84c26478689'), 'tweet_id': 1254036795777585152, 'text': "@DONJAZZY please sir help me,I need your help I want to get mummy somethings and me to sustain till Corona virus holiday end please,my father is no more,I'm part of the people given my younger bro &amp;sis one in a while please help me,thanks bro https://t.co/vvXiSjhYhC https://t.co/0NhAH6GdrO", 'hashtags': [], 'user': {'user_id': 1250890797404377091, 'name': '@iamolasunkanmidon', 'screen_name': 'iamolasunkanmi2'}, 'created_at': datetime.datetime(2020, 4, 25, 13, 17, 25)}

# %%
query = "COVID19InTurkeysPrisons"
results = tweets_collection.find({ "hashtags": query });

for result in results:
    print(result)
# Out:
# {'_id': ObjectId('66256f5aecffc84c2646ae55'), 'tweet_id': 1249403768023678982, 'text': 'In Turkey, there are 300 thousand prisoners and 150 thousand prison employees in prisons. \nPrisons are the most risky places in case of corona virus.\nThe lives of thousands of people are at risk.\n\n#COVID19InTurkeysPrisons\n\n@SusannaCeccardi', 'hashtags': ['COVID19InTurkeysPrisons'], 'user': {'user_id': 1225145123920588805, 'name': 'efe09', 'screen_name': 'efe0927183508'}, 'created_at': datetime.datetime(2020, 4, 12, 18, 27, 25)}
# {'_id': ObjectId('66256f5aecffc84c2646ae57'), 'tweet_id': 1249403769567227906, 'text': 'Turkey is so stubborn to change their mind, they want innocent babies and their mothers, journalists, lawyers, doctors, human rights activists to die! Corona virus is spreading rapidly in Turkish prisons. They need to be released immediately! @hrw \n\n#COVID19InTurkeysPrisons', 'hashtags': ['COVID19InTurkeysPrisons'], 'user': {'user_id': 1230170166614482944, 'name': 'Carpe diem', 'screen_name': 'Carpedi92670638'}, 'created_at': datetime.datetime(2020, 4, 12, 18, 27, 26)}
# {'_id': ObjectId('66256f5aecffc84c2646ae60'), 'tweet_id': 1249403773178560515, 'text': 'In Turkey, there are 300 thousand prisoners and 150 thousand prison employees in prisons. Prisons are the most risky places in case of corona virüs. The lives of thousands of people are at risk.\n Ahmet Altan\n#COVID19InTurkeysPrisons https://t.co/NH6Gs9BNbZ', 'hashtags': ['COVID19InTurkeysPrisons'], 'user': {'user_id': 1220761862452776965, 'name': 'Ruh-u Revan', 'screen_name': 'Brateki19662327'}, 'created_at': datetime.datetime(2020, 4, 12, 18, 27, 26)}
# {'_id': ObjectId('66256f5aecffc84c2646ae72'), 'tweet_id': 1249403778136256513, 'text': 'In Turkey, there are 300 thousand prisoners and 150 thousand prison employees in prisons. Prisons are the most risky places in case of corona virüs. The lives of thousands of people are at risk.\n\n#COVID19InTurkeysPrisons', 'hashtags': ['COVID19InTurkeysPrisons'], 'user': {'user_id': 755762321440514049, 'name': 'CHN', 'screen_name': 'ChnBba'}, 'created_at': datetime.datetime(2020, 4, 12, 18, 27, 28)}
# {'_id': ObjectId('66256f5aecffc84c2646ae8c'), 'tweet_id': 1249403785832738816, 'text': 'Turkey is so stubborn to change their mind, they want innocent babies and their mothers, journalists, lawyers, doctors, human rights activists to die! Corona virus is spreading rapidly in Turkish prisons. They need to be released immediately! @hrw \n\n#COVID19InTurkeysPrisons', 'hashtags': ['COVID19InTurkeysPrisons'], 'user': {'user_id': 1246029295367204865, 'name': 'Abdullah Akbulut', 'screen_name': 'AbdullahAkbu'}, 'created_at': datetime.datetime(2020, 4, 12, 18, 27, 29)}
# {'_id': ObjectId('66256f5aecffc84c2646aece'), 'tweet_id': 1249403804279283718, 'text': "Corona spreads very fast! Prisons in Turkey are not hygienic.\n\n✅Pregnants,\n✅Women with children,\n✅Cancers,\n✅Chronic patients,\n✅Political prisoners!\n\nMust be urgently released from prison. World can't keep calm to this risk!\n\n#COVID19InTurkeysPrisons https://t.co/FVJ45e5BXK", 'hashtags': ['COVID19InTurkeysPrisons'], 'user': {'user_id': 1241409976280723458, 'name': 'İbtisar', 'screen_name': 'ibtisar2'}, 'created_at': datetime.datetime(2020, 4, 12, 18, 27, 34)}
# {'_id': ObjectId('66256f5aecffc84c2646aefd'), 'tweet_id': 1249403818221199360, 'text': 'In Turkey, there are 300 thousand prisoners and 150 thousand prison employees in prisons. Prisons are the most risky places in case of corona virüs. The lives of thousands of people are at risk.\n\n#COVID19InTurkeysPrisons', 'hashtags': ['COVID19InTurkeysPrisons'], 'user': {'user_id': 1236946149036175361, 'name': 'Yalçın Yalçın', 'screen_name': 'YalnYal73214968'}, 'created_at': datetime.datetime(2020, 4, 12, 18, 27, 37)}
# {'_id': ObjectId('66256f5aecffc84c2646af1d'), 'tweet_id': 1249403827519979522, 'text': 'Corona does not discriminate Why does the state discriminate while making laws?\n\n#COVID19InTurkeysPrisons https://t.co/oosjO69qJW', 'hashtags': ['COVID19InTurkeysPrisons'], 'user': {'user_id': 1139115788059774977, 'name': 'Fatihyavuzmurad', 'screen_name': 'fatihyavuzmurad'}, 'created_at': datetime.datetime(2020, 4, 12, 18, 27, 39)}
# {'_id': ObjectId('66256f5aecffc84c2646af22'), 'tweet_id': 1249403828895649794, 'text': 'In Turkey, there are 300 thousand prisoners and 150 thousand prison employees in prisons. Prisons are the most risky places in case of corona virüs. The lives of thousands of people are at risk.\n\n#COVID19InTurkeysPrisons', 'hashtags': ['COVID19InTurkeysPrisons'], 'user': {'user_id': 1020969421655953408, 'name': 'Mehtapcm', 'screen_name': 'BrenAddy'}, 'created_at': datetime.datetime(2020, 4, 12, 18, 27, 40)}
# {'_id': ObjectId('66256f5aecffc84c2646af5d'), 'tweet_id': 1249403844712452096, 'text': 'Turkey is so stubborn to change their mind, they want innocent babies and their mothers, journalists, lawyers, doctors, human rights activists to die! Corona virus is spreading rapidly in Turkish prisons. They need to be released immediately! @hrw \n\n#COVID19InTurkeysPrisons', 'hashtags': ['COVID19InTurkeysPrisons'], 'user': {'user_id': 1235567466295824385, 'name': 'Yusufun Bekler', 'screen_name': 'tasbalta59591'}, 'created_at': datetime.datetime(2020, 4, 12, 18, 27, 44)}
# {'_id': ObjectId('66256f5aecffc84c2646af67'), 'tweet_id': 1249403847371632646, 'text': 'Waiting for the evacuation, there are\n\n✅780 babies\n✅2,500 children\n✅Thousands of political prisoners\n✅1,333 Patients\n✅457 Severe patients\n\nLet these people be evacuated before they are infected by corona virus.\n\n#COVID19InTurkeysPrisons https://t.co/27PF0A1NZR', 'hashtags': ['COVID19InTurkeysPrisons'], 'user': {'user_id': 1143580403602771969, 'name': 'İlknur Aydın', 'screen_name': 'lknurAy68761902'}, 'created_at': datetime.datetime(2020, 4, 12, 18, 27, 44)}
# {'_id': ObjectId('66256f5aecffc84c2646af68'), 'tweet_id': 1249403848315338752, 'text': 'Sanchez-Amor EP Rapporteur for Turkey:\n\'\' Due to the corona virus,the Turkish government\'s plan to bring amnesty is positive.\n\nIt\'s time to release hundreds of journalists, academics, lawyers and human rights defenders who have been unjustly arrested. "\n\n#COVID19InTurkeysPrisons', 'hashtags': ['COVID19InTurkeysPrisons'], 'user': {'user_id': 1243608102219452480, 'name': 'Ayşe Küçük', 'screen_name': 'AyeKk29078760'}, 'created_at': datetime.datetime(2020, 4, 12, 18, 27, 44)}
# {'_id': ObjectId('66256f5aecffc84c2646af79'), 'tweet_id': 1249403853910487040, 'text': 'Sanchez-Amor EP Rapporteur for Turkey:\n\'\' Due to the corona virus,the Turkish government\'s plan to bring amnesty is positive.\n\nIt\'s time to release hundreds of journalists, academics, lawyers and human rights defenders who have been unjustly arrested. "\n\n#COVID19InTurkeysPrisons', 'hashtags': ['COVID19InTurkeysPrisons'], 'user': {'user_id': 1236967780311797760, 'name': 'Aslı', 'screen_name': 'Asli56271235'}, 'created_at': datetime.datetime(2020, 4, 12, 18, 27, 46)}
# {'_id': ObjectId('66256f5aecffc84c2646af88'), 'tweet_id': 1249403857995776002, 'text': 'Waiting for the evacuation, there are\n\n✅780 babies\n✅2,500 children\n✅Thousands of political prisoners\n✅1,333 Patients\n✅457 Severe patients\n\nLet these people be evacuated before they are infected by corona virus.\n\n#COVID19InTurkeysPrisons', 'hashtags': ['COVID19InTurkeysPrisons'], 'user': {'user_id': 967707888260124672, 'name': 'Evliya Bingöl', 'screen_name': 'EvliyaBingol'}, 'created_at': datetime.datetime(2020, 4, 12, 18, 27, 47)}
# {'_id': ObjectId('66256f5aecffc84c2646af9b'), 'tweet_id': 1249403865419612162, 'text': 'Turkey is so stubborn to change their mind, they want innocent babies and their mothers, journalists, lawyers, doctors, human rights activists to die! Corona virus is spreading rapidly in Turkish prisons. They need to be released immediately! @hrw \n\n#COVID19InTurkeysPrisons', 'hashtags': ['COVID19InTurkeysPrisons'], 'user': {'user_id': 592732220, 'name': 'Lokman Avşar', 'screen_name': 'avsarlokman'}, 'created_at': datetime.datetime(2020, 4, 12, 18, 27, 48)}
# {'_id': ObjectId('66256f5aecffc84c2646afad'), 'tweet_id': 1249403869391736834, 'text': 'As the corona spreads so fast, the incarcerated lawyers, judges, prosecutors, teachers, officers must be released immediately. Do not discriminate people that is against the law.\nBecause they are only teacher, lawyer, doctor. \n@jeremycorbyn\n#COVID19InTurkeysPrisons', 'hashtags': ['COVID19InTurkeysPrisons'], 'user': {'user_id': 1210306772688396289, 'name': 'Uğurlu', 'screen_name': 'Uurlu52924984'}, 'created_at': datetime.datetime(2020, 4, 12, 18, 27, 49)}
# {'_id': ObjectId('66256f5aecffc84c2646afb4'), 'tweet_id': 1249403870645751809, 'text': 'Duymaz sesini masumun....\nGörmeyen kulak\nKonuşmayan göz\nDuymayan dil \nHaaa corona duy bizi, GiT buradan demişiz haaa bunlara ses verin bize demişiz.... \nAynı şey\n\n#COVID19InTurkeysPrisons', 'hashtags': ['COVID19InTurkeysPrisons'], 'user': {'user_id': 4608992535, 'name': 'Bahar🌞', 'screen_name': 'gali359'}, 'created_at': datetime.datetime(2020, 4, 12, 18, 27, 50)}
# {'_id': ObjectId('66256f5aecffc84c2646afba'), 'tweet_id': 1249403871031590912, 'text': 'Corona does not discriminate Why does the state discriminate while making laws?\n\n#COVID19InTurkeysPrisons', 'hashtags': ['COVID19InTurkeysPrisons'], 'user': {'user_id': 1225145123920588805, 'name': 'efe09', 'screen_name': 'efe0927183508'}, 'created_at': datetime.datetime(2020, 4, 12, 18, 27, 50)}
# {'_id': ObjectId('66256f5aecffc84c2646afd3'), 'tweet_id': 1249403880544391171, 'text': "Corona spreads very fast! Prisons in Turkey are not hygienic.\n\n✅Pregnants,\n✅Women with children,\n✅Cancers,\n✅Chronic patients,\n✅Political prisoners!\n\nMust be urgently released from prison. World can't keep calm to this risk!\n\n#COVID19InTurkeysPrisons https://t.co/FVJ45e5BXK", 'hashtags': ['COVID19InTurkeysPrisons'], 'user': {'user_id': 1210312753698787329, 'name': 'Cemil Balaban', 'screen_name': 'CemilBalaban15'}, 'created_at': datetime.datetime(2020, 4, 12, 18, 27, 52)}
# {'_id': ObjectId('66256f5aecffc84c2646afea'), 'tweet_id': 1249403887498428418, 'text': 'In Turkey, there are 300 thousand prisoners and 150 thousand prison employees in prisons. Prisons are the most risky places in case of corona virüs. The lives of thousands of people are at risk.\n Ahmet Altan\n#COVID19InTurkeysPrisons https://t.co/I82iDeP5xH', 'hashtags': ['COVID19InTurkeysPrisons'], 'user': {'user_id': 1190688993257631752, 'name': 'Kadir', 'screen_name': 'Kadir72836815'}, 'created_at': datetime.datetime(2020, 4, 12, 18, 27, 54)}
# {'_id': ObjectId('66256f5aecffc84c2646afee'), 'tweet_id': 1249403888224124928, 'text': 'Corona does not discriminate Why does the state discriminate while making laws?\n\n#COVID19InTurkeysPrisons', 'hashtags': ['COVID19InTurkeysPrisons'], 'user': {'user_id': 1167830796255813632, 'name': 'Lehrer', 'screen_name': 'Lehrer53886133'}, 'created_at': datetime.datetime(2020, 4, 12, 18, 27, 54)}
# {'_id': ObjectId('66256f5becffc84c2646affe'), 'tweet_id': 1249403892707753986, 'text': 'Sanchez-Amor EP Rapporteur for Turkey:\n\'\' Due to the corona virus,the Turkish government\'s plan to bring amnesty is positive.\n\nIt\'s time to release hundreds of journalists, academics, lawyers and human rights defenders who have been unjustly arrested. "\n\n#COVID19InTurkeysPrisons', 'hashtags': ['COVID19InTurkeysPrisons'], 'user': {'user_id': 1133676612468269057, 'name': 'Bedevi', 'screen_name': 'Bedevi28492667'}, 'created_at': datetime.datetime(2020, 4, 12, 18, 27, 55)}
# {'_id': ObjectId('66256f5becffc84c2646b006'), 'tweet_id': 1249403895249620994, 'text': 'In Turkey, there are 300 thousand prisoners and 150 thousand prison employees in prisons. \nPrisons are the most risky places in case of corona virus.\n Commission members and Parliament should decide on the principle of equality. @KatiPiri\n\n#COVID19InTurkeysPrisons', 'hashtags': ['COVID19InTurkeysPrisons'], 'user': {'user_id': 1243097668529934336, 'name': 'Melek Acar', 'screen_name': 'MelekAcar35'}, 'created_at': datetime.datetime(2020, 4, 12, 18, 27, 56)}
# {'_id': ObjectId('66256f5becffc84c2646b010'), 'tweet_id': 1249403897380298754, 'text': 'In Turkey, there are 300 thousand prisoners and 150 thousand prison employees in prisons. \nPrisons are the most risky places in case of corona virus.\nThe lives of thousands of people are at risk.\n\n#COVID19InTurkeysPrisons\n\n@SusannaCeccardi', 'hashtags': ['COVID19InTurkeysPrisons'], 'user': {'user_id': 948148560964530176, 'name': 'Ümit', 'screen_name': 'umutluyum2018'}, 'created_at': datetime.datetime(2020, 4, 12, 18, 27, 56)}
# {'_id': ObjectId('66256f5becffc84c2646b01e'), 'tweet_id': 1249403903692734464, 'text': 'In Turkey, there are 300 thousand prisoners and 150 thousand prison employees in prisons. Prisons are the most risky places in case of corona virüs. The lives of thousands of people are at risk.\n Ahmet Altan\n#COVID19InTurkeysPrisons https://t.co/NH6Gs9BNbZ', 'hashtags': ['COVID19InTurkeysPrisons'], 'user': {'user_id': 1244371331677851648, 'name': 'Selin', 'screen_name': 'selin_demirc'}, 'created_at': datetime.datetime(2020, 4, 12, 18, 27, 58)}
# {'_id': ObjectId('66256f5becffc84c2646b022'), 'tweet_id': 1249403906041548800, 'text': 'Turkey is so stubborn to change their mind, they want innocent babies and their mothers, journalists, lawyers, doctors, human rights activists to die! Corona virus is spreading rapidly in Turkish prisons. They need to be released immediately! @hrw \n\n#COVID19InTurkeysPrisons', 'hashtags': ['COVID19InTurkeysPrisons'], 'user': {'user_id': 1236967780311797760, 'name': 'Aslı', 'screen_name': 'Asli56271235'}, 'created_at': datetime.datetime(2020, 4, 12, 18, 27, 58)}
# {'_id': ObjectId('66256f5becffc84c2646b028'), 'tweet_id': 1249403896562319361, 'text': '#COVID19InTurkeysPrisons\n\n@RebHarms', 'hashtags': ['COVID19InTurkeysPrisons'], 'user': {'user_id': 1233262154163408897, 'name': 'Hakan Yurdakul', 'screen_name': 'HakanYu32315772'}, 'created_at': datetime.datetime(2020, 4, 12, 18, 27, 56)}
# {'_id': ObjectId('66256f5becffc84c2646b031'), 'tweet_id': 1249403911292817409, 'text': 'This old lady faced terrorism(!) charge and was arrested. Although she is in the risk group for Corona, she is not released.  \n\nWhy?\n\n@vonderleyen\n\n#COVID19InTurkeysPrisons', 'hashtags': ['COVID19InTurkeysPrisons'], 'user': {'user_id': 1236302702239416320, 'name': 'Brc', 'screen_name': 'kovagillerden'}, 'created_at': datetime.datetime(2020, 4, 12, 18, 27, 59)}
# {'_id': ObjectId('66256f5becffc84c2646b03a'), 'tweet_id': 1249403915017347073, 'text': 'In Turkey, there are 300 thousand prisoners and 150 thousand prison employees in prisons. \nPrisons are the most risky places in case of corona virus.\n Commission members and Parliament should decide on the principle of equality. @KatiPiri\n\n#COVID19InTurkeysPrisons', 'hashtags': ['COVID19InTurkeysPrisons'], 'user': {'user_id': 2936365717, 'name': 'SILA', 'screen_name': 'sila_vefa'}, 'created_at': datetime.datetime(2020, 4, 12, 18, 28)}
# {'_id': ObjectId('66256f5becffc84c2646b066'), 'tweet_id': 1249403928170713096, 'text': 'In Turkey, there are 300 thousand prisoners and 150 thousand prison employees in prisons. Prisons are the most risky places in case of corona virüs. The lives of thousands of people are at risk.\n\n#COVID19InTurkeysPrisons', 'hashtags': ['COVID19InTurkeysPrisons'], 'user': {'user_id': 1178936571346784256, 'name': 'AbbasSonYolcu', 'screen_name': 'SonYolcuAbbas55'}, 'created_at': datetime.datetime(2020, 4, 12, 18, 28, 3)}
# {'_id': ObjectId('66256f5becffc84c2646b076'), 'tweet_id': 1249403931958149121, 'text': 'Waiting for the evacuation, there are\n\n✅780 babies\n✅2,500 children\n✅Thousands of political prisoners\n✅1,333 Patients\n✅457 Severe patients\n\nLet these people be evacuated before they are infected by corona virus.\n\n#COVID19InTurkeysPrisons https://t.co/27PF0A1NZR', 'hashtags': ['COVID19InTurkeysPrisons'], 'user': {'user_id': 805033477959745537, 'name': 'Hakan US', 'screen_name': 'academicturk'}, 'created_at': datetime.datetime(2020, 4, 12, 18, 28, 4)}
# {'_id': ObjectId('66256f5becffc84c2646b0b3'), 'tweet_id': 1249403952904503296, 'text': 'Turkey is so stubborn to change their mind, they want innocent babies and their mothers, journalists, lawyers, doctors, human rights activists to die! Corona virus is spreading rapidly in Turkish prisons. They need to be released immediately! @hrw \n\n#COVID19InTurkeysPrisons', 'hashtags': ['COVID19InTurkeysPrisons'], 'user': {'user_id': 1047196944936964097, 'name': 'Mevlüt Şahin Yücesoy', 'screen_name': 'msyucesoy42'}, 'created_at': datetime.datetime(2020, 4, 12, 18, 28, 9)}
# {'_id': ObjectId('66256f5becffc84c2646b0b7'), 'tweet_id': 1249403953562951682, 'text': 'In Turkey, there are 300 thousand prisoners and 150 thousand prison employees in prisons. \nPrisons are the most risky places in case of corona virus.\nThe lives of thousands of people are at risk.\n\n#COVID19InTurkeysPrisons\n\n@SusannaCeccardi', 'hashtags': ['COVID19InTurkeysPrisons'], 'user': {'user_id': 1186760088805097475, 'name': 'Aliefe', 'screen_name': 'EfharistoK'}, 'created_at': datetime.datetime(2020, 4, 12, 18, 28, 9)}
# {'_id': ObjectId('66256f5becffc84c2646b0cf'), 'tweet_id': 1249403959409815556, 'text': 'In Turkey, there are 300 thousand prisoners and 150 thousand prison employees in prisons. Prisons are the most risky places in case of corona virüs. The lives of thousands of people are at risk.\n\n#COVID19InTurkeysPrisons', 'hashtags': ['COVID19InTurkeysPrisons'], 'user': {'user_id': 1045001851177971712, 'name': 'Seren', 'screen_name': 'Seren2045'}, 'created_at': datetime.datetime(2020, 4, 12, 18, 28, 11)}
# {'_id': ObjectId('66256f5becffc84c2646b0d6'), 'tweet_id': 1249403960701698056, 'text': 'In Turkey, there are 300 thousand prisoners and 150 thousand prison employees in prisons. Prisons are the most risky places in case of corona virüs. The lives of thousands of people are at risk.\n Ahmet Altan\n#COVID19InTurkeysPrisons https://t.co/I82iDeP5xH', 'hashtags': ['COVID19InTurkeysPrisons'], 'user': {'user_id': 799218071454027776, 'name': 'aydın', 'screen_name': 'hakperestdir'}, 'created_at': datetime.datetime(2020, 4, 12, 18, 28, 11)}
# {'_id': ObjectId('66256f5becffc84c2646b0dd'), 'tweet_id': 1249403961808912391, 'text': 'Turkey has currently a total of 1564 prisoners, including 560 seriously ill ones.\n\n This number should not increase any more with the corona virus.\n#COVID19InTurkeysPrisons https://t.co/MYmd5FmQsq', 'hashtags': ['COVID19InTurkeysPrisons'], 'user': {'user_id': 1222081230033780736, 'name': 'ŞahımAli', 'screen_name': 'mali_sah'}, 'created_at': datetime.datetime(2020, 4, 12, 18, 28, 11)}
# {'_id': ObjectId('66256f5becffc84c2646b0df'), 'tweet_id': 1249403962438098944, 'text': 'Sanchez-Amor EP Rapporteur for Turkey:\n\'\' Due to the corona virus,the Turkish government\'s plan to bring amnesty is positive.\n\nIt\'s time to release hundreds of journalists, academics, lawyers and human rights defenders who have been unjustly arrested. "\n\n#COVID19InTurkeysPrisons', 'hashtags': ['COVID19InTurkeysPrisons'], 'user': {'user_id': 1219370013804679176, 'name': 'Mehmet Yiğit', 'screen_name': 'Yolcu90838439'}, 'created_at': datetime.datetime(2020, 4, 12, 18, 28, 12)}
# {'_id': ObjectId('66256f5becffc84c2646b13e'), 'tweet_id': 1249403990464397312, 'text': 'In Turkey, there are 300 thousand prisoners and 150 thousand prison employees in prisons. Prisons are the most risky places in case of corona virüs. The lives of thousands of people are at risk.\n Ahmet Altan\n#COVID19InTurkeysPrisons https://t.co/NH6Gs9BNbZ', 'hashtags': ['COVID19InTurkeysPrisons'], 'user': {'user_id': 1006162470912843776, 'name': 'Betül Durmaz', 'screen_name': 'BetulDurmaz49'}, 'created_at': datetime.datetime(2020, 4, 12, 18, 28, 18)}
# {'_id': ObjectId('66256f5becffc84c2646b153'), 'tweet_id': 1249403995107581955, 'text': 'Corona does not discriminate Why does the state discriminate while making laws?\n\n#COVID19InTurkeysPrisons', 'hashtags': ['COVID19InTurkeysPrisons'], 'user': {'user_id': 1647252990, 'name': 'M', 'screen_name': 'yasatmaideali11'}, 'created_at': datetime.datetime(2020, 4, 12, 18, 28, 19)}
# {'_id': ObjectId('66256f5becffc84c2646b159'), 'tweet_id': 1249403996315344896, 'text': 'Waiting for the evacuation, there are\n\n✅780 babies\n✅2,500 children\n✅Thousands of political prisoners\n✅1,333 Patients\n✅457 Severe patients\n\nLet these people be evacuated before they are infected by corona virus.\n\n#COVID19InTurkeysPrisons https://t.co/27PF0A1NZR', 'hashtags': ['COVID19InTurkeysPrisons'], 'user': {'user_id': 1188508693979189248, 'name': 'RuhunuÖzgürBırak', 'screen_name': 'kr41883667'}, 'created_at': datetime.datetime(2020, 4, 12, 18, 28, 20)}
# {'_id': ObjectId('66256f5becffc84c2646b171'), 'tweet_id': 1249404001986240512, 'text': 'Sanchez-Amor EP Rapporteur for Turkey:\n\'\' Due to the corona virus,the Turkish government\'s plan to bring amnesty is positive.\n\nIt\'s time to release hundreds of journalists, academics, lawyers and human rights defenders who have been unjustly arrested. "\n\n#COVID19InTurkeysPrisons', 'hashtags': ['COVID19InTurkeysPrisons'], 'user': {'user_id': 744647169987219456, 'name': 'NUR', 'screen_name': 'son1umut1'}, 'created_at': datetime.datetime(2020, 4, 12, 18, 28, 21)}
# {'_id': ObjectId('66256f5becffc84c2646b189'), 'tweet_id': 1249404004754432001, 'text': 'In Turkey, there are 300 thousand prisoners and 150 thousand prison employees in prisons. Prisons are the most risky places in case of corona virüs. The lives of thousands of people are at risk.\n\n#COVID19InTurkeysPrisons', 'hashtags': ['COVID19InTurkeysPrisons'], 'user': {'user_id': 928303241770819585, 'name': 'Kemal', 'screen_name': 'FKMLKemall0'}, 'created_at': datetime.datetime(2020, 4, 12, 18, 28, 22)}
# {'_id': ObjectId('66256f5becffc84c2646b18b'), 'tweet_id': 1249404005446569984, 'text': '2-) Nowadays these victims are in prisons with 40 persons in rooms for 7-10 persons.\n\nThese people are arrested because of political reasons. They must be outside for avoiding from Corona Virus.\n@FLOTUS\n@EUCouncil  @Schwarzenegger @BAMF_Dialog @KenRoth \n #COVID19InTurkeysPrisons', 'hashtags': ['COVID19InTurkeysPrisons'], 'user': {'user_id': 1174451728848236544, 'name': 'Ismail', 'screen_name': 'Ismail36687829'}, 'created_at': datetime.datetime(2020, 4, 12, 18, 28, 22)}
# {'_id': ObjectId('66256f5becffc84c2646b1b0'), 'tweet_id': 1249404015387054081, 'text': 'Turkey is so stubborn to change their mind, they want innocent babies and their mothers, journalists, lawyers, doctors, human rights activists to die! Corona virus is spreading rapidly in Turkish prisons. They need to be released immediately! @hrw \n\n#COVID19InTurkeysPrisons', 'hashtags': ['COVID19InTurkeysPrisons'], 'user': {'user_id': 1198254416991866880, 'name': 'Meryem', 'screen_name': 'Meryem38731577'}, 'created_at': datetime.datetime(2020, 4, 12, 18, 28, 24)}
# {'_id': ObjectId('66256f5becffc84c2646b1dd'), 'tweet_id': 1249404031283453955, 'text': 'Waiting for the evacuation, there are\n\n◇780 babies\n◇2,500 children\n◇Thousands of political prisoners\n◇1,333 Patients\n◇457 Severe patients\n\nLet these people be evacuated before they are infected by corona virus.\n\n#COVID19InTurkeysPrisons https://t.co/yDyoT6e4ju', 'hashtags': ['COVID19InTurkeysPrisons'], 'user': {'user_id': 912991964173410305, 'name': 'Anadolu', 'screen_name': 'AnodoluVefa'}, 'created_at': datetime.datetime(2020, 4, 12, 18, 28, 28)}
# {'_id': ObjectId('66256f5becffc84c2646b1e1'), 'tweet_id': 1249404031862095872, 'text': 'People from Hizmet Movement are kept in prison just because they opposed to Erdogan..though the great risk of death caused by Corona..doesn’t it mean to take a person’s living right from him?\n\n#COVID19InTurkeysPrisons', 'hashtags': ['COVID19InTurkeysPrisons'], 'user': {'user_id': 1165528066338279424, 'name': 'sahraaa_', 'screen_name': 'sahraaa30884147'}, 'created_at': datetime.datetime(2020, 4, 12, 18, 28, 28)}
# {'_id': ObjectId('66256f5becffc84c2646b1ee'), 'tweet_id': 1249404035364540417, 'text': 'While the number of deaths in Turkey is increasing every day because of CORONA. Why the state discriminates people in case of evictions ?\n\n#COVID19InTurkeysPrisons', 'hashtags': ['COVID19InTurkeysPrisons'], 'user': {'user_id': 1245047384004067329, 'name': 'KEISER2', 'screen_name': 'KEISER26'}, 'created_at': datetime.datetime(2020, 4, 12, 18, 28, 29)}
# {'_id': ObjectId('66256f5becffc84c2646b1fd'), 'tweet_id': 1249404038346674176, 'text': 'Sanchez-Amor EP Rapporteur for Turkey:\n\'\' Due to the corona virus,the Turkish government\'s plan to bring amnesty is positive.\n\nIt\'s time to release hundreds of journalists, academics, lawyers and human rights defenders who have been unjustly arrested. "\n\n#COVID19InTurkeysPrisons', 'hashtags': ['COVID19InTurkeysPrisons'], 'user': {'user_id': 1239890705264361472, 'name': 'Arife', 'screen_name': 'Arife76049415'}, 'created_at': datetime.datetime(2020, 4, 12, 18, 28, 30)}
# {'_id': ObjectId('66256f5becffc84c2646b205'), 'tweet_id': 1249404040389279746, 'text': 'Corona does not discriminate Why does the state discriminate while making laws?\n\n#COVID19InTurkeysPrisons https://t.co/oosjO69qJW', 'hashtags': ['COVID19InTurkeysPrisons'], 'user': {'user_id': 928303241770819585, 'name': 'Kemal', 'screen_name': 'FKMLKemall0'}, 'created_at': datetime.datetime(2020, 4, 12, 18, 28, 30)}
# {'_id': ObjectId('66256f5becffc84c2646b20d'), 'tweet_id': 1249404043237232643, 'text': 'Waiting for the evacuation, there are\n\n✅780 babies\n✅2,500 children\n✅Thousands of political prisoners\n✅1,333 Patients\n✅457 Severe patients\n\nLet these people be evacuated before they are infected by corona virus.\n\n#COVID19InTurkeysPrisons https://t.co/27PF0A1NZR', 'hashtags': ['COVID19InTurkeysPrisons'], 'user': {'user_id': 1161013041481338880, 'name': 'Yusuf Özgendi', 'screen_name': 'YOzgendi'}, 'created_at': datetime.datetime(2020, 4, 12, 18, 28, 31)}
# {'_id': ObjectId('66256f5becffc84c2646b216'), 'tweet_id': 1249404045028188164, 'text': 'In Turkey, there are 300 thousand prisoners and 150 thousand prison employees in prisons. Prisons are the most risky places in case of corona virüs. The lives of thousands of people are at risk.\n\n#COVID19InTurkeysPrisons', 'hashtags': ['COVID19InTurkeysPrisons'], 'user': {'user_id': 1243183237637312514, 'name': 'YUSUF ARMAĞAN', 'screen_name': 'YUSUFARMAAN13'}, 'created_at': datetime.datetime(2020, 4, 12, 18, 28, 31)}
# {'_id': ObjectId('66256f5becffc84c2646b21f'), 'tweet_id': 1249404047121174528, 'text': 'Sanchez-Amor EP Rapporteur for Turkey:\n\'\' Due to the corona virus,the Turkish government\'s plan to bring amnesty is positive.\n\nIt\'s time to release hundreds of journalists, academics, lawyers and human rights defenders who have been unjustly arrested. "\n\n#COVID19InTurkeysPrisons', 'hashtags': ['COVID19InTurkeysPrisons'], 'user': {'user_id': 3985672097, 'name': 'sinan', 'screen_name': 'sinan8690'}, 'created_at': datetime.datetime(2020, 4, 12, 18, 28, 32)}
# {'_id': ObjectId('66256f5becffc84c2646b224'), 'tweet_id': 1249404047997755392, 'text': 'In Turkey, there are 300 thousand prisoners and 150 thousand prison employees in prisons. Prisons are the most risky places in case of corona virüs. The lives of thousands of people are at risk.\n Ahmet Altan\n#COVID19InTurkeysPrisons https://t.co/NH6Gs9BNbZ', 'hashtags': ['COVID19InTurkeysPrisons'], 'user': {'user_id': 1239890705264361472, 'name': 'Arife', 'screen_name': 'Arife76049415'}, 'created_at': datetime.datetime(2020, 4, 12, 18, 28, 32)}
# {'_id': ObjectId('66256f5becffc84c2646b228'), 'tweet_id': 1249404049142755329, 'text': 'Corona spreads very fast! Prisons in Turkey are not hygienic.\n\nPregnants,\nWomen with children,\nCancers,\nChronic patients,\nPolitical prisoners!\n\nMust be urgently released from prison.\n\n#COVID19InTurkeysPrisons', 'hashtags': ['COVID19InTurkeysPrisons'], 'user': {'user_id': 1242877416336474113, 'name': 'Lalekosan', 'screen_name': 'lalekosan'}, 'created_at': datetime.datetime(2020, 4, 12, 18, 28, 32)}
# {'_id': ObjectId('66256f5becffc84c2646b229'), 'tweet_id': 1249404049260191744, 'text': 'Corona does not discriminate Why does the state discriminate while making laws?\n\n#COVID19InTurkeysPrisons https://t.co/oosjO69qJW', 'hashtags': ['COVID19InTurkeysPrisons'], 'user': {'user_id': 3129911939, 'name': 'امينة   سالم', 'screen_name': '96457c5608b5458'}, 'created_at': datetime.datetime(2020, 4, 12, 18, 28, 32)}
# {'_id': ObjectId('66256f5becffc84c2646b233'), 'tweet_id': 1249404051680374784, 'text': 'In Turkey, there are 300 thousand prisoners and 150 thousand prison employees in prisons. Prisons are the most risky places in case of corona virüs. The lives of thousands of people are at risk.\n Ahmet Altan\n#COVID19InTurkeysPrisons https://t.co/NH6Gs9BNbZ', 'hashtags': ['COVID19InTurkeysPrisons'], 'user': {'user_id': 1219370013804679176, 'name': 'Mehmet Yiğit', 'screen_name': 'Yolcu90838439'}, 'created_at': datetime.datetime(2020, 4, 12, 18, 28, 33)}
# {'_id': ObjectId('66256f5becffc84c2646b281'), 'tweet_id': 1249404077676670976, 'text': 'Sanchez-Amor EP Rapporteur for Turkey:\n\'\' Due to the corona virus,the Turkish government\'s plan to bring amnesty is positive.\n\nIt\'s time to release hundreds of journalists, academics, lawyers and human rights defenders who have been unjustly arrested. "\n\n#COVID19InTurkeysPrisons', 'hashtags': ['COVID19InTurkeysPrisons'], 'user': {'user_id': 951451357197807616, 'name': 'suya perçin', 'screen_name': 'Okyar5234'}, 'created_at': datetime.datetime(2020, 4, 12, 18, 28, 39)}
# {'_id': ObjectId('66256f5becffc84c2646b28d'), 'tweet_id': 1249404079949914114, 'text': 'Corona,which is now a global threatening for millions ,has been killing so many people all over the world and it is also a great danger for those in prison.Please free prisoners immediately!\n\n#COVID19InTurkeysPrisons https://t.co/s85pvCPzQy', 'hashtags': ['COVID19InTurkeysPrisons'], 'user': {'user_id': 1245047384004067329, 'name': 'KEISER2', 'screen_name': 'KEISER26'}, 'created_at': datetime.datetime(2020, 4, 12, 18, 28, 40)}
# {'_id': ObjectId('66256f5becffc84c2646b29f'), 'tweet_id': 1249404085234806793, 'text': 'Waiting for the evacuation, there are\n\n✅780 babies\n✅2,500 children\n✅Thousands of political prisoners\n✅1,333 Patients\n✅457 Severe patients\n\nLet these people be evacuated before they are infected by corona virus.\n\n#COVID19InTurkeysPrisons https://t.co/27PF0A1NZR', 'hashtags': ['COVID19InTurkeysPrisons'], 'user': {'user_id': 3569756897, 'name': 'Deniz', 'screen_name': 'denizgunes14'}, 'created_at': datetime.datetime(2020, 4, 12, 18, 28, 41)}
# {'_id': ObjectId('66256f5becffc84c2646b2a5'), 'tweet_id': 1249404089005486086, 'text': '#COVID19InTurkeysPrisons\n\nplease do something about the situation in Turkey. Even the children , women are still in prison. There is corona virus threaten but Erdogan regime is doing nothing about it', 'hashtags': ['COVID19InTurkeysPrisons'], 'user': {'user_id': 1104081010264866820, 'name': 'Fatih Fatih', 'screen_name': 'is_mat_ak'}, 'created_at': datetime.datetime(2020, 4, 12, 18, 28, 42)}
# {'_id': ObjectId('66256f5becffc84c2646b2a9'), 'tweet_id': 1249404089651408904, 'text': 'Turkey is so stubborn to change their mind, they want innocent babies and their mothers, journalists, lawyers, doctors, human rights activists to die! Corona virus is spreading rapidly in Turkish prisons. They need to be released immediately! @hrw \n\n#COVID19InTurkeysPrisons', 'hashtags': ['COVID19InTurkeysPrisons'], 'user': {'user_id': 705721122814369792, 'name': "People's Panel on Human Rights", 'screen_name': 'PPHRtweets'}, 'created_at': datetime.datetime(2020, 4, 12, 18, 28, 42)}
# {'_id': ObjectId('66256f5becffc84c2646b2d0'), 'tweet_id': 1249404101441589250, 'text': 'German Yeşil Party ex-co-chairman Cem Özdemir: Turkish prisons are frightening in case of setting deadly traps for Corona.\n Adequate hygiene and medical care is the human right of all prisoners! \n\nAll innocent prisoners must be released immediately. \n\n#COVID19InTurkeysPrisons', 'hashtags': ['COVID19InTurkeysPrisons'], 'user': {'user_id': 532322765, 'name': 'mustafa', 'screen_name': 'mhafiz69'}, 'created_at': datetime.datetime(2020, 4, 12, 18, 28, 45)}
# {'_id': ObjectId('66256f5becffc84c2646b2d1'), 'tweet_id': 1249404101491855361, 'text': 'Waiting for the evacuation, there are\n- 780 babies\n- 2,500 children\n- Thousands of political prisoners\n- 1,333 Patients\n- 457 Severe patients\nLet these people be evacuated before they are infected by corona virus.\n\n#COVID19InTurkeysPrisons', 'hashtags': ['COVID19InTurkeysPrisons'], 'user': {'user_id': 1248909760772165632, 'name': 'Hatice(yeni)', 'screen_name': 'Hatice44064402'}, 'created_at': datetime.datetime(2020, 4, 12, 18, 28, 45)}
# {'_id': ObjectId('66256f5becffc84c2646b2d3'), 'tweet_id': 1249404102267809794, 'text': 'In Turkey, there are 300 thousand prisoners and 150 thousand prison employees in prisons. Prisons are the most risky places in case of corona virüs. The lives of thousands of people are at risk.\n\n#COVID19InTurkeysPrisons', 'hashtags': ['COVID19InTurkeysPrisons'], 'user': {'user_id': 1188508693979189248, 'name': 'RuhunuÖzgürBırak', 'screen_name': 'kr41883667'}, 'created_at': datetime.datetime(2020, 4, 12, 18, 28, 45)}
# {'_id': ObjectId('66256f5becffc84c2646b31a'), 'tweet_id': 1249404122434015233, 'text': 'There are 760 babies in prison. Corona can be dangerous for them.\nWe just want justice...\n#COVID19InTurkeysPrisons', 'hashtags': ['COVID19InTurkeysPrisons'], 'user': {'user_id': 1045001851177971712, 'name': 'Seren', 'screen_name': 'Seren2045'}, 'created_at': datetime.datetime(2020, 4, 12, 18, 28, 50)}
# {'_id': ObjectId('66256f5becffc84c2646b327'), 'tweet_id': 1249404126276059136, 'text': 'Corona does not discriminate Why does the state discriminate while making laws?\n\n#COVID19InTurkeysPrisons https://t.co/oosjO69qJW', 'hashtags': ['COVID19InTurkeysPrisons'], 'user': {'user_id': 935696855207415808, 'name': 'Michael', 'screen_name': 'Michael44zero'}, 'created_at': datetime.datetime(2020, 4, 12, 18, 28, 51)}
# {'_id': ObjectId('66256f5becffc84c2646b34d'), 'tweet_id': 1249404137663496192, 'text': 'There are 760 babies in prison. Corona can be dangerous for them.\nWe just want justice...\n#COVID19InTurkeysPrisons', 'hashtags': ['COVID19InTurkeysPrisons'], 'user': {'user_id': 1243563559096848388, 'name': 'NiluferPoyrazoglu', 'screen_name': 'NiluferPoyrazo1'}, 'created_at': datetime.datetime(2020, 4, 12, 18, 28, 53)}
# {'_id': ObjectId('66256f5becffc84c2646b38e'), 'tweet_id': 1249404161097154560, 'text': 'Corona does not discriminate Why does the state discriminate while making laws?\n\n#COVID19InTurkeysPrisons https://t.co/oosjO69qJW', 'hashtags': ['COVID19InTurkeysPrisons'], 'user': {'user_id': 1128910500341932032, 'name': 'lavinya', 'screen_name': 'khadije78'}, 'created_at': datetime.datetime(2020, 4, 12, 18, 28, 59)}
# {'_id': ObjectId('66256f5becffc84c2646b394'), 'tweet_id': 1249404162867068931, 'text': '#COVID19InTurkeysPrisons\nYES', 'hashtags': ['COVID19InTurkeysPrisons'], 'user': {'user_id': 573393688, 'name': 'fethi SENCER', 'screen_name': 'fethisencer'}, 'created_at': datetime.datetime(2020, 4, 12, 18, 28, 59)}
# {'_id': ObjectId('66256f5becffc84c2646b3a7'), 'tweet_id': 1249404167665455107, 'text': '#COVID19InTurkeysPrisons', 'hashtags': ['COVID19InTurkeysPrisons'], 'user': {'user_id': 1248909760772165632, 'name': 'Hatice(yeni)', 'screen_name': 'Hatice44064402'}, 'created_at': datetime.datetime(2020, 4, 12, 18, 29, 1)}
# {'_id': ObjectId('66256f5becffc84c2646b3bd'), 'tweet_id': 1249404174091067395, 'text': 'In Turkey, there are 300 thousand prisoners and 150 thousand prison employees in prisons. \nPrisons are the most risky places in case of corona virus.\n Commission members and Parliament should decide on the principle of equality. @KatiPiri\n\n#COVID19InTurkeysPrisons', 'hashtags': ['COVID19InTurkeysPrisons'], 'user': {'user_id': 948148560964530176, 'name': 'Ümit', 'screen_name': 'umutluyum2018'}, 'created_at': datetime.datetime(2020, 4, 12, 18, 29, 2)}
# {'_id': ObjectId('66256f5becffc84c2646b3f2'), 'tweet_id': 1249404187429031937, 'text': 'Turkey has currently a total of 1564 prisoners, including 560 seriously ill ones.\n\n This number should not increase any more with the corona virus.\n#COVID19InTurkeysPrisons \n@eucopresident @CharlesMichel', 'hashtags': ['COVID19InTurkeysPrisons'], 'user': {'user_id': 1244955833387139072, 'name': 'Canan', 'screen_name': 'Canan91328739'}, 'created_at': datetime.datetime(2020, 4, 12, 18, 29, 5)}
# {'_id': ObjectId('66256f5becffc84c2646b40e'), 'tweet_id': 1249404197268840448, 'text': 'In Turkey, there are 300 thousand prisoners and 150 thousand prison employees in prisons. Prisons are the most risky places in case of corona virüs. The lives of thousands of people are at risk.\n\n#COVID19InTurkeysPrisons', 'hashtags': ['COVID19InTurkeysPrisons'], 'user': {'user_id': 2949093705, 'name': 'Alien 👽☠️', 'screen_name': 'yaseminn2452'}, 'created_at': datetime.datetime(2020, 4, 12, 18, 29, 8)}
# {'_id': ObjectId('66256f5becffc84c2646b41d'), 'tweet_id': 1249404202461343747, 'text': 'Waiting for the evacuation, there are\n\n✅780 babies\n✅2,500 children\n✅Thousands of political prisoners\n✅1,333 Patients\n✅457 Severe patients\n\nLet these people be evacuated before they are infected by corona virus.\n\n#COVID19InTurkeysPrisons https://t.co/27PF0A1NZR', 'hashtags': ['COVID19InTurkeysPrisons'], 'user': {'user_id': 914518442757251074, 'name': 'Neşide Yıldız', 'screen_name': 'neside_z'}, 'created_at': datetime.datetime(2020, 4, 12, 18, 29, 9)}
# {'_id': ObjectId('66256f5becffc84c2646b439'), 'tweet_id': 1249404212708020225, 'text': 'İktidar, İnfaz yasasında adil ve eşit olmayacak...\n\nŞiddete bulaşmamış siyasi suçluları cezaevinde corona virüsü ile başbaşa bırakmak istiyor...\n\nTüm dünya sizi izliyor UNUTMAYIN\nÖlüme imza atmayın...\nYaşatmayı seçin...\n\n@abdulhamitgul\n\n#COVID19InTurkeysPrisons', 'hashtags': ['COVID19InTurkeysPrisons'], 'user': {'user_id': 1148352228010446848, 'name': 'Brussel ZC', 'screen_name': 'BrusselZC'}, 'created_at': datetime.datetime(2020, 4, 12, 18, 29, 11)}
# {'_id': ObjectId('66256f5becffc84c2646b441'), 'tweet_id': 1249404214134157313, 'text': 'İktidar, İnfaz yasasında adil ve eşit olmayacak...\n\nŞiddete bulaşmamış siyasi suçluları cezaevinde corona virüsü ile başbaşa bırakmak istiyor...\n\nTüm dünya sizi izliyor UNUTMAYIN\nÖlüme imza atmayın...\nYaşatmayı seçin...\n\n@abdulhamitgul\n\n#COVID19InTurkeysPrisons', 'hashtags': ['COVID19InTurkeysPrisons'], 'user': {'user_id': 2710735315, 'name': 'gizlisaklisir', 'screen_name': 'AEticin'}, 'created_at': datetime.datetime(2020, 4, 12, 18, 29, 12)}
# {'_id': ObjectId('66256f5becffc84c2646b45a'), 'tweet_id': 1249404223378333704, 'text': 'Corona is spreading fast! Prisons are not hygienic. \nPregnant women,\nWomen with children,\nCancer patients, \nChronic patients, \nPolitical prisoners!\nWhat is he doing in prison\n\n#COVID19InTurkeysPrisons https://t.co/Nyxep6mHc5', 'hashtags': ['COVID19InTurkeysPrisons'], 'user': {'user_id': 1143580403602771969, 'name': 'İlknur Aydın', 'screen_name': 'lknurAy68761902'}, 'created_at': datetime.datetime(2020, 4, 12, 18, 29, 14)}
# {'_id': ObjectId('66256f5becffc84c2646b464'), 'tweet_id': 1249404225341345792, 'text': 'Waiting for the evacuation, there are\n\n✅780 babies\n✅2,500 children\n✅Thousands of political prisoners\n✅1,333 Patients\n✅457 Severe patients\n\nLet these people be evacuated before they are infected by corona virus.\n\n#COVID19InTurkeysPrisons https://t.co/27PF0A1NZR', 'hashtags': ['COVID19InTurkeysPrisons'], 'user': {'user_id': 893184797081817089, 'name': 'Akarsu', 'screen_name': 'Pskakarsu'}, 'created_at': datetime.datetime(2020, 4, 12, 18, 29, 14)}
# {'_id': ObjectId('66256f5becffc84c2646b471'), 'tweet_id': 1249404229107748864, 'text': 'Waiting for the evacuation, there are\n\n✅780 babies\n✅2,500 children\n✅Thousands of political prisoners\n✅1,333 Patients\n✅457 Severe patients\n\nLet these people be evacuated before they are infected by corona virus.\n\n#COVID19InTurkeysPrisons https://t.co/27PF0A1NZR', 'hashtags': ['COVID19InTurkeysPrisons'], 'user': {'user_id': 1241809300709879808, 'name': 'lasey', 'screen_name': 'lasey76420443'}, 'created_at': datetime.datetime(2020, 4, 12, 18, 29, 15)}
# {'_id': ObjectId('66256f5becffc84c2646b496'), 'tweet_id': 1249404237085368323, 'text': 'Duymaz sesini masumun....\nGörmeyen kulak\nKonuşmayan göz\nDuymayan dil \nHaaa corona duy bizi, GiT buradan demişiz haaa bunlara ses verin bize demişiz.... \nAynı şey\n\n#COVID19InTurkeysPrisons', 'hashtags': ['COVID19InTurkeysPrisons'], 'user': {'user_id': 1143985140772888576, 'name': 'Neslihan Altınmakas', 'screen_name': 'NeslihanNmakas'}, 'created_at': datetime.datetime(2020, 4, 12, 18, 29, 17)}
# {'_id': ObjectId('66256f5becffc84c2646b4a6'), 'tweet_id': 1249404241078300678, 'text': 'In Turkey, there are 300 thousand prisoners and 150 thousand prison employees in prisons. Prisons are the most risky places in case of corona virüs. The lives of thousands of people are at risk.\n\n#COVID19InTurkeysPrisons', 'hashtags': ['COVID19InTurkeysPrisons'], 'user': {'user_id': 1236649416909602816, 'name': 'Güzel insan', 'screen_name': 'Guzel_insan0634'}, 'created_at': datetime.datetime(2020, 4, 12, 18, 29, 18)}
# {'_id': ObjectId('66256f5becffc84c2646b4ac'), 'tweet_id': 1249404241875263490, 'text': 'Waiting for the evacuation, there are\n- 780 babies\n- 2,500 children\n- Thousands of political prisoners\n- 1,333 Patients\n- 457 Severe patients\nLet these people be evacuated before they are infected by corona virus.\n#COVID19InTurkeysPrisons https://t.co/0AuWNZrwB2', 'hashtags': ['COVID19InTurkeysPrisons'], 'user': {'user_id': 1222081230033780736, 'name': 'ŞahımAli', 'screen_name': 'mali_sah'}, 'created_at': datetime.datetime(2020, 4, 12, 18, 29, 18)}
# {'_id': ObjectId('66256f5becffc84c2646b4b9'), 'tweet_id': 1249404244375060487, 'text': 'Sanchez-Amor EP Rapporteur for Turkey:\n\'\' Due to the corona virus,the Turkish government\'s plan to bring amnesty is positive.\n\nIt\'s time to release hundreds of journalists, academics, lawyers and human rights defenders who have been unjustly arrested. "\n\n#COVID19InTurkeysPrisons', 'hashtags': ['COVID19InTurkeysPrisons'], 'user': {'user_id': 1194185550539952129, 'name': 'Emine erdem', 'screen_name': 'Emineer56800191'}, 'created_at': datetime.datetime(2020, 4, 12, 18, 29, 19)}
# {'_id': ObjectId('66256f5becffc84c2646b4ca'), 'tweet_id': 1249404249504714753, 'text': 'In Turkey, there are 300 thousand prisoners and 150 thousand prison employees in prisons. Prisons are the most risky places in case of corona virüs. The lives of thousands of people are at risk.\n\n#COVID19InTurkeysPrisons', 'hashtags': ['COVID19InTurkeysPrisons'], 'user': {'user_id': 1239861040231452672, 'name': 'Ertuğrul Koçak', 'screen_name': 'ErturulVera11'}, 'created_at': datetime.datetime(2020, 4, 12, 18, 29, 20)}
# {'_id': ObjectId('66256f5becffc84c2646b4cb'), 'tweet_id': 1249404249626345477, 'text': 'Waiting for the evacuation, there are\n\n✅780 babies\n✅2,500 children\n✅Thousands of political prisoners\n✅1,333 Patients\n✅457 Severe patients\n\nLet these people be evacuated before they are infected by corona virus.\n\n#COVID19InTurkeysPrisons https://t.co/27PF0A1NZR', 'hashtags': ['COVID19InTurkeysPrisons'], 'user': {'user_id': 1236957674463531008, 'name': 'GREEN WHITE', 'screen_name': 'GREENWH66758582'}, 'created_at': datetime.datetime(2020, 4, 12, 18, 29, 20)}
# {'_id': ObjectId('66256f5becffc84c2646b4d8'), 'tweet_id': 1249404253887762432, 'text': 'Waiting for the evacuation, there are\n\n✅780 babies\n✅2,500 children\n✅Thousands of political prisoners\n✅1,333 Patients\n✅457 Severe patients\n\nLet these people be evacuated before they are infected by corona virus.\n\n#COVID19InTurkeysPrisons https://t.co/27PF0A1NZR', 'hashtags': ['COVID19InTurkeysPrisons'], 'user': {'user_id': 900720603937861632, 'name': '💕MUTLU, GELECEK💕', 'screen_name': 'mutlusevdamm'}, 'created_at': datetime.datetime(2020, 4, 12, 18, 29, 21)}
# {'_id': ObjectId('66256f5becffc84c2646b4e8'), 'tweet_id': 1249404259621167104, 'text': 'Corona does not discriminate Why does the state discriminate while making laws?\n\n#COVID19InTurkeysPrisons https://t.co/oosjO69qJW', 'hashtags': ['COVID19InTurkeysPrisons'], 'user': {'user_id': 756254708470255616, 'name': 'Lebrîz', 'screen_name': 'lebriz0'}, 'created_at': datetime.datetime(2020, 4, 12, 18, 29, 22)}
# {'_id': ObjectId('66256f5becffc84c2646b503'), 'tweet_id': 1249404266021883904, 'text': 'İktidar, İnfaz yasasında adil ve eşit olmayacak...\n\nŞiddete bulaşmamış siyasi suçluları cezaevinde corona virüsü ile başbaşa bırakmak istiyor...\n\nTüm dünya sizi izliyor UNUTMAYIN\nÖlüme imza atmayın...\nYaşatmayı seçin...\n\n@abdulhamitgul\n\n#COVID19InTurkeysPrisons', 'hashtags': ['COVID19InTurkeysPrisons'], 'user': {'user_id': 1148574937797582848, 'name': 'SHERIF', 'screen_name': 'Esref486'}, 'created_at': datetime.datetime(2020, 4, 12, 18, 29, 24)}
# {'_id': ObjectId('66256f5becffc84c2646b508'), 'tweet_id': 1249404267955400708, 'text': 'In Turkey, there are 300 thousand prisoners and 150 thousand prison employees in prisons. Prisons are the most risky places in case of corona virüs. The lives of thousands of people are at risk.\n\n#COVID19InTurkeysPrisons', 'hashtags': ['COVID19InTurkeysPrisons'], 'user': {'user_id': 861587880694755328, 'name': 'mucize', 'screen_name': 'ayra2006'}, 'created_at': datetime.datetime(2020, 4, 12, 18, 29, 24)}
# {'_id': ObjectId('66256f5becffc84c2646b527'), 'tweet_id': 1249404278227316738, 'text': 'Waiting for the evacuation, there are\n- 780 babies\n- 2,500 children\n- Thousands of political prisoners\n- 1,333 Patients\n- 457 Severe patients\nLet these people be evacuated before they are infected by corona virus.\n#COVID19InTurkeysPrisons https://t.co/0AuWNZrwB2', 'hashtags': ['COVID19InTurkeysPrisons'], 'user': {'user_id': 1244040172708167682, 'name': 'GuzideEvde🏡', 'screen_name': 'EvdeGuzide'}, 'created_at': datetime.datetime(2020, 4, 12, 18, 29, 27)}
# {'_id': ObjectId('66256f5becffc84c2646b541'), 'tweet_id': 1249404283709243393, 'text': 'In Turkey, there are 300 thousand prisoners and 150 thousand prison employees in prisons. Prisons are the most risky places in case of corona virüs. The lives of thousands of people are at risk.\n\n#COVID19InTurkeysPrisons', 'hashtags': ['COVID19InTurkeysPrisons'], 'user': {'user_id': 1211077558223028224, 'name': 'Ali Kerem', 'screen_name': '11Alive00'}, 'created_at': datetime.datetime(2020, 4, 12, 18, 29, 28)}
# {'_id': ObjectId('66256f5becffc84c2646b585'), 'tweet_id': 1249404306454953985, 'text': 'In Turkey, there are 300 thousand prisoners and 150 thousand prison employees in prisons. Prisons are the most risky places in case of corona virüs. The lives of thousands of people are at risk.\n\n#COVID19InTurkeysPrisons', 'hashtags': ['COVID19InTurkeysPrisons'], 'user': {'user_id': 1242546643326701572, 'name': 'zihni safi', 'screen_name': 'SafiZihni'}, 'created_at': datetime.datetime(2020, 4, 12, 18, 29, 34)}
# {'_id': ObjectId('66256f5becffc84c2646b594'), 'tweet_id': 1249404312037531649, 'text': 'In Turkey, there are 300 thousand prisoners and 150 thousand prison employees in prisons. Prisons are the most risky places in case of corona virüs. The lives of thousands of people are at risk.\n\n#COVID19InTurkeysPrisons', 'hashtags': ['COVID19InTurkeysPrisons'], 'user': {'user_id': 1248909760772165632, 'name': 'Hatice(yeni)', 'screen_name': 'Hatice44064402'}, 'created_at': datetime.datetime(2020, 4, 12, 18, 29, 35)}
# ...
# {'_id': ObjectId('66256f5fecffc84c2646f489'), 'tweet_id': 1249408767437033472, 'text': 'In Turkey, there are 300 thousand prisoners and 150 thousand prison employees in prisons. Prisons are the riskiest places in the case of corona virüs. The lives of thousands of people are at risk.\n\n #COVID19InTurkeysPrisons https://t.co/Ydzegqrfjz', 'hashtags': ['COVID19InTurkeysPrisons'], 'user': {'user_id': 1244955833387139072, 'name': 'Canan', 'screen_name': 'Canan91328739'}, 'created_at': datetime.datetime(2020, 4, 12, 18, 47, 17)}
# {'_id': ObjectId('66256f5fecffc84c2646f497'), 'tweet_id': 1249408771455139844, 'text': '#COVID19InTurkeysPrisons\n\n@RebHarms', 'hashtags': ['COVID19InTurkeysPrisons'], 'user': {'user_id': 1244346910988800007, 'name': 'Gül Nur', 'screen_name': 'GlAnadolu2'}, 'created_at': datetime.datetime(2020, 4, 12, 18, 47, 18)}
# {'_id': ObjectId('66256f5fecffc84c2646f49b'), 'tweet_id': 1249408771882913793, 'text': 'Doctors in Şakran prison where my wife is also kept in, have tested positive for Corona. Thousands of people’s lives are at risk. Those of the high-risk group with chronic bronchitis like my wife are especially at risk.\n#COVID19InTurkeysPrisons\n @tfajon\n @CoESpokesperson https://t.co/QLd9ZAG4PA', 'hashtags': ['COVID19InTurkeysPrisons'], 'user': {'user_id': 1235206392463732737, 'name': 'Xyzabc', 'screen_name': 'Xyzabc63914250'}, 'created_at': datetime.datetime(2020, 4, 12, 18, 47, 18)}
# {'_id': ObjectId('66256f5fecffc84c2646f49d'), 'tweet_id': 1249408772021387265, 'text': 'In Turkey, there are 300 thousand prisoners and 150 thousand prison employees in prisons. Prisons are the most risky places in case of corona virüs. The lives of thousands of people are at risk.\n Ahmet Altan\n#COVID19InTurkeysPrisons https://t.co/NH6Gs9BNbZ', 'hashtags': ['COVID19InTurkeysPrisons'], 'user': {'user_id': 1128910500341932032, 'name': 'lavinya', 'screen_name': 'khadije78'}, 'created_at': datetime.datetime(2020, 4, 12, 18, 47, 18)}
# {'_id': ObjectId('66256f5fecffc84c2646f4c4'), 'tweet_id': 1249408786386821120, 'text': 'Turkey has currently a total of 1564 prisoners, including 560 seriously ill ones.\nThis number should not increase any more with the corona virus.\n\n@RebHarms\n\n#COVID19InTurkeysPrisons', 'hashtags': ['COVID19InTurkeysPrisons'], 'user': {'user_id': 2948456405, 'name': 'AysePernur', 'screen_name': 'aysepernur'}, 'created_at': datetime.datetime(2020, 4, 12, 18, 47, 22)}
# {'_id': ObjectId('66256f5fecffc84c2646f4e3'), 'tweet_id': 1249408793454055424, 'text': 'Please do something about the situation in Turkey. Even the children , women are still in prison. There is corona virus threaten but Erdogan regime is doing nothing about it \n#COVID19InTurkeysPrisons', 'hashtags': ['COVID19InTurkeysPrisons'], 'user': {'user_id': 1244371447847387136, 'name': 'Maviyelken2020', 'screen_name': 'maviyelken2020'}, 'created_at': datetime.datetime(2020, 4, 12, 18, 47, 23)}
# {'_id': ObjectId('66256f5fecffc84c2646f525'), 'tweet_id': 1249408812836179968, 'text': 'People ,who have their relatives in the prisons without no reason ,have the trouble of Corona danger for those they love now.. This is not justice..stop this pain immediately!\n\n #COVID19InTurkeysPrisons', 'hashtags': ['COVID19InTurkeysPrisons'], 'user': {'user_id': 1244346910988800007, 'name': 'Gül Nur', 'screen_name': 'GlAnadolu2'}, 'created_at': datetime.datetime(2020, 4, 12, 18, 47, 28)}
# {'_id': ObjectId('66256f5fecffc84c2646f526'), 'tweet_id': 1249408812844552193, 'text': 'In Turkey, there are 300 thousand prisoners and 150 thousand prison employees in prisons. Prisons are the most risky places in case of corona virüs. The lives of thousands of people are at risk.\n\n#COVID19InTurkeysPrisons', 'hashtags': ['COVID19InTurkeysPrisons'], 'user': {'user_id': 1175485346, 'name': 'M. Burtacgiray', 'screen_name': 'GBurtac'}, 'created_at': datetime.datetime(2020, 4, 12, 18, 47, 28)}
# {'_id': ObjectId('66256f5fecffc84c2646f533'), 'tweet_id': 1249408817617657856, 'text': 'İktidar, İnfaz yasasında adil ve eşit olmayacak...\n\nŞiddete bulaşmamış siyasi suçluları cezaevinde corona virüsü ile başbaşa bırakmak istiyor...\n\nTüm dünya sizi izliyor UNUTMAYIN\nÖlüme imza atmayın...\nYaşatmayı seçin...\n\n@abdulhamitgul\n\n#COVID19InTurkeysPrisons', 'hashtags': ['COVID19InTurkeysPrisons'], 'user': {'user_id': 1242344282813595654, 'name': 'SavaŞ.KılınC', 'screen_name': 'savaKlnc3'}, 'created_at': datetime.datetime(2020, 4, 12, 18, 47, 29)}
# {'_id': ObjectId('66256f5fecffc84c2646f536'), 'tweet_id': 1249408818028728323, 'text': 'Turkey has currently a total of 1564 prisoners, including 560 seriously ill ones.\nThis number should not increase any more with the corona virus.\n\n#COVID19InTurkeysPrisons', 'hashtags': ['COVID19InTurkeysPrisons'], 'user': {'user_id': 1229508589112483841, 'name': 'zelihaselma', 'screen_name': 'Thelitt49878473'}, 'created_at': datetime.datetime(2020, 4, 12, 18, 47, 29)}
# {'_id': ObjectId('66256f5fecffc84c2646f53f'), 'tweet_id': 1249408819421016064, 'text': 'Turkey has currently a total of 1564 prisoners, including 560 seriously ill ones.\nThis number should not increase any more with the corona virus.\n\n#COVID19InTurkeysPrisons', 'hashtags': ['COVID19InTurkeysPrisons'], 'user': {'user_id': 2225537360, 'name': 'Sadece birazcık huzur 😊🙏', 'screen_name': '01truthteller'}, 'created_at': datetime.datetime(2020, 4, 12, 18, 47, 30)}
# {'_id': ObjectId('66256f5fecffc84c2646f549'), 'tweet_id': 1249408822218719236, 'text': 'Sanchez-Amor EP Rapporteur for Turkey:\n\'\' Due to the corona virus,the Turkish government\'s plan to bring amnesty is positive.\n\nIt\'s time to release hundreds of journalists, academics, lawyers and human rights defenders who have been unjustly arrested. "\n\n#COVID19InTurkeysPrisons', 'hashtags': ['COVID19InTurkeysPrisons'], 'user': {'user_id': 1242166076059910146, 'name': 'Asya', 'screen_name': 'Asya_Koral'}, 'created_at': datetime.datetime(2020, 4, 12, 18, 47, 30)}
# {'_id': ObjectId('66256f5fecffc84c2646f550'), 'tweet_id': 1249408824374693889, 'text': 'innocent people should be evacuated\n\n 780 babies\n\n 2,500 children\n\n Thousands of political prisoners\n\n 1,333 Patients\n\n 457 Severe patients Allow these individuals to be evacuated before the corona virus is transmitted.\n\n #COVID19InTurkeysPrisons\n\n@KatiPiri  @BorisJohnson', 'hashtags': ['COVID19InTurkeysPrisons'], 'user': {'user_id': 1249403248714199040, 'name': 'astw', 'screen_name': 'astw44889299'}, 'created_at': datetime.datetime(2020, 4, 12, 18, 47, 31)}
# {'_id': ObjectId('66256f5fecffc84c2646f56a'), 'tweet_id': 1249408831920185347, 'text': "Bu istifa eden bakanlar, \n\nCorona'dan mı kaçıyorlar\n\n  ⤵️😎👏👇🙏😅⤵️\n #COVID19InTurkeysPrisons", 'hashtags': ['COVID19InTurkeysPrisons'], 'user': {'user_id': 1166816928670867458, 'name': 'Polat', 'screen_name': 'Polat60570246'}, 'created_at': datetime.datetime(2020, 4, 12, 18, 47, 33)}
# {'_id': ObjectId('66256f5fecffc84c2646f56f'), 'tweet_id': 1249408833996361730, 'text': 'Corona,which is now a global threatening for millions ,has been killing so many people all over the world and it is also a great danger for those in prison.Please free prisoners immediately!\n\n#COVID19InTurkeysPrisons https://t.co/s85pvCPzQy', 'hashtags': ['COVID19InTurkeysPrisons'], 'user': {'user_id': 944624959309205506, 'name': 'abuzer', 'screen_name': 'abuzer90733859'}, 'created_at': datetime.datetime(2020, 4, 12, 18, 47, 33)}
# {'_id': ObjectId('66256f5fecffc84c2646f573'), 'tweet_id': 1249408834709454852, 'text': 'We have been saying that it has been corona virus for a month.  Authorities say there is no Corona.\nTwo people died in the prisons.  Being imprisoned is injustice.The authorities are responsible for human deaths.\nYou cannot give your account to the public\n#COVID19InTurkeysPrisons', 'hashtags': ['COVID19InTurkeysPrisons'], 'user': {'user_id': 1083743628625772544, 'name': 'Y. Aydın', 'screen_name': '7275_xyzt'}, 'created_at': datetime.datetime(2020, 4, 12, 18, 47, 33)}
# {'_id': ObjectId('66256f5fecffc84c2646f57d'), 'tweet_id': 1249408837024722945, 'text': 'Turkey has currently a total of 1564 prisoners, including 560 seriously ill ones.\nThis number should not increase any more with the corona virus.\n\n#COVID19InTurkeysPrisons', 'hashtags': ['COVID19InTurkeysPrisons'], 'user': {'user_id': 1175485346, 'name': 'M. Burtacgiray', 'screen_name': 'GBurtac'}, 'created_at': datetime.datetime(2020, 4, 12, 18, 47, 34)}
# {'_id': ObjectId('66256f5fecffc84c2646f5b5'), 'tweet_id': 1249408850589081600, 'text': 'Doctors in Şakran prison where my wife is also kept in, have tested positive for Corona. Thousands of people’s lives are at risk. Those of the high-risk group with chronic bronchitis like my wife are especially at risk.\n#COVID19InTurkeysPrisons\n @tfajon\n @CoESpokesperson https://t.co/QLd9ZAG4PA', 'hashtags': ['COVID19InTurkeysPrisons'], 'user': {'user_id': 2408607213, 'name': 'ALP ERSİN KAYA', 'screen_name': 'alpertunga672'}, 'created_at': datetime.datetime(2020, 4, 12, 18, 47, 37)}
# {'_id': ObjectId('66256f5fecffc84c2646f5e1'), 'tweet_id': 1249408864409325568, 'text': 'Turkey has currently a total of 1564 prisoners, including 560 seriously ill ones.\nThis number should not increase any more with the corona virus.\n\n#COVID19InTurkeysPrisons', 'hashtags': ['COVID19InTurkeysPrisons'], 'user': {'user_id': 933063031109636096, 'name': '🇹🇷🇽🇰RabiaSahin🇦🇱🇬🇧', 'screen_name': 'hafsahajrullahi'}, 'created_at': datetime.datetime(2020, 4, 12, 18, 47, 40)}
# {'_id': ObjectId('66256f5fecffc84c2646f5e4'), 'tweet_id': 1249408864602271744, 'text': 'Corona does not discriminate Why does the state discriminate while making laws?\n\n#COVID19InTurkeysPrisons https://t.co/oosjO69qJW', 'hashtags': ['COVID19InTurkeysPrisons'], 'user': {'user_id': 1237019805560995840, 'name': 'Ömer', 'screen_name': 'mer61735097'}, 'created_at': datetime.datetime(2020, 4, 12, 18, 47, 40)}
# {'_id': ObjectId('66256f5fecffc84c2646f603'), 'tweet_id': 1249408874626637827, 'text': 'Turkey has currently a total of 1564 prisoners, including 560 seriously ill ones.\nThis number should not increase any more with the corona virus.\n\n#COVID19InTurkeysPrisons', 'hashtags': ['COVID19InTurkeysPrisons'], 'user': {'user_id': 1097397693037596672, 'name': 'Merlin', 'screen_name': 'Merlin48901251'}, 'created_at': datetime.datetime(2020, 4, 12, 18, 47, 43)}
# {'_id': ObjectId('66256f5fecffc84c2646f604'), 'tweet_id': 1249408874836303873, 'text': 'In Turkey, there are 300 thousand prisoners and 150 thousand prison employees in prisons. Prisons are the riskiest places in the case of corona virüs. The lives of thousands of people are at risk.\n\n #COVID19InTurkeysPrisons https://t.co/Ydzegqrfjz', 'hashtags': ['COVID19InTurkeysPrisons'], 'user': {'user_id': 933063031109636096, 'name': '🇹🇷🇽🇰RabiaSahin🇦🇱🇬🇧', 'screen_name': 'hafsahajrullahi'}, 'created_at': datetime.datetime(2020, 4, 12, 18, 47, 43)}
# {'_id': ObjectId('66256f5fecffc84c2646f607'), 'tweet_id': 1249408876455309313, 'text': "Corona spreads very fast! Prisons in Turkey are not hygienic.\n\n✅Pregnants,\n✅Women with children,\n✅Cancers,\n✅Chronic patients,\n✅Political prisoners!\n\nMust be urgently released from prison. World can't keep calm to this risk!\n\n#COVID19InTurkeysPrisons https://t.co/FVJ45e5BXK", 'hashtags': ['COVID19InTurkeysPrisons'], 'user': {'user_id': 1243510213518471174, 'name': 'MARİA NİTO', 'screen_name': 'maria_nito4'}, 'created_at': datetime.datetime(2020, 4, 12, 18, 47, 43)}
# {'_id': ObjectId('66256f5fecffc84c2646f614'), 'tweet_id': 1249408882016948226, 'text': 'Turkey has currently a total of 1564 prisoners, including 560 seriously ill ones.\nThis number should not increase any more with the corona virus.\n\n#COVID19InTurkeysPrisons', 'hashtags': ['COVID19InTurkeysPrisons'], 'user': {'user_id': 2539437612, 'name': '🇹🇷Koray🇳🇴', 'screen_name': 'KORAY1912KSK'}, 'created_at': datetime.datetime(2020, 4, 12, 18, 47, 45)}
# {'_id': ObjectId('66256f5fecffc84c2646f617'), 'tweet_id': 1249408882776125441, 'text': 'Turkey has currently a total of 1564 prisoners, including 560 seriously ill ones.\nThis number should not increase any more with the corona virus.\n\n#COVID19InTurkeysPrisons', 'hashtags': ['COVID19InTurkeysPrisons'], 'user': {'user_id': 1049648191984033794, 'name': 'Melisa', 'screen_name': 'Halimelale1'}, 'created_at': datetime.datetime(2020, 4, 12, 18, 47, 45)}
# {'_id': ObjectId('66256f5fecffc84c2646f619'), 'tweet_id': 1249408883141083147, 'text': 'Turkey has currently a total of 1564 prisoners, including 560 seriously ill ones.\nThis number should not increase any more with the corona virus.\n\n#COVID19InTurkeysPrisons', 'hashtags': ['COVID19InTurkeysPrisons'], 'user': {'user_id': 1233217313131892737, 'name': 'huzur', 'screen_name': 'qrm109'}, 'created_at': datetime.datetime(2020, 4, 12, 18, 47, 45)}
# {'_id': ObjectId('66256f5fecffc84c2646f62c'), 'tweet_id': 1249408887494717447, 'text': '#COVID19InTurkeysPrisons', 'hashtags': ['COVID19InTurkeysPrisons'], 'user': {'user_id': 1210693218880413700, 'name': 'Etka', 'screen_name': 'Etka54190900'}, 'created_at': datetime.datetime(2020, 4, 12, 18, 47, 46)}
# {'_id': ObjectId('66256f5fecffc84c2646f631'), 'tweet_id': 1249408888534962183, 'text': 'Waiting for the evacuation, there are\n\n✅780 babies\n✅2,500 children\n✅Thousands of political prisoners\n✅1,333 Patients\n✅457 Severe patients\n\nLet these people be evacuated before they are infected by corona virus.\n\n#COVID19InTurkeysPrisons https://t.co/qAcYQSb8Wp', 'hashtags': ['COVID19InTurkeysPrisons'], 'user': {'user_id': 2463140704, 'name': 'ahdevefa', 'screen_name': 'viktorblacks'}, 'created_at': datetime.datetime(2020, 4, 12, 18, 47, 46)}
# {'_id': ObjectId('66256f5fecffc84c2646f653'), 'tweet_id': 1249408897674285057, 'text': "Sanchez-Amor European Parliament Rapporteur for Turkey \n#COVID19InTurkeysPrisons https://t.co/3QE2O0nfo4\n  '' Due to the corona virus, the Turkish government's plan to bring amnesty is positive.", 'hashtags': ['COVID19InTurkeysPrisons'], 'user': {'user_id': 799218071454027776, 'name': 'aydın', 'screen_name': 'hakperestdir'}, 'created_at': datetime.datetime(2020, 4, 12, 18, 47, 48)}
# {'_id': ObjectId('66256f5fecffc84c2646f65b'), 'tweet_id': 1249408899544952832, 'text': 'Turkey has currently a total of 1564 prisoners, including 560 seriously ill ones.\nThis number should not increase any more with the corona virus.\n\n#COVID19InTurkeysPrisons', 'hashtags': ['COVID19InTurkeysPrisons'], 'user': {'user_id': 1242916974675382272, 'name': 'mem', 'screen_name': 'mem94378496'}, 'created_at': datetime.datetime(2020, 4, 12, 18, 47, 49)}
# {'_id': ObjectId('66256f5fecffc84c2646f67b'), 'tweet_id': 1249408910362120200, 'text': 'Turkey has currently a total of 1564 prisoners, including 560 seriously ill ones.\nThis number should not increase any more with the corona virus.\n\n@RebHarms\n\n#COVID19InTurkeysPrisons', 'hashtags': ['COVID19InTurkeysPrisons'], 'user': {'user_id': 1230170166614482944, 'name': 'Carpe diem', 'screen_name': 'Carpedi92670638'}, 'created_at': datetime.datetime(2020, 4, 12, 18, 47, 51)}
# {'_id': ObjectId('66256f5fecffc84c2646f681'), 'tweet_id': 1249408912618655744, 'text': '#COVID19InTurkeysPrisons\n\nWhile the number of deaths in Turkey is increasing every day because of CORONA. Why the state discriminates people in case of evictions ?', 'hashtags': ['COVID19InTurkeysPrisons'], 'user': {'user_id': 1025658981543550977, 'name': 'rukiye', 'screen_name': 'marslimiymneyim'}, 'created_at': datetime.datetime(2020, 4, 12, 18, 47, 52)}
# {'_id': ObjectId('66256f5fecffc84c2646f685'), 'tweet_id': 1249408913218441216, 'text': 'Corona does not discriminate Why does the state discriminate while making laws?\n\n#COVID19InTurkeysPrisons https://t.co/oosjO69qJW', 'hashtags': ['COVID19InTurkeysPrisons'], 'user': {'user_id': 1218123108873396224, 'name': 'Murat35', 'screen_name': 'Murat3565613205'}, 'created_at': datetime.datetime(2020, 4, 12, 18, 47, 52)}

# %%
user_id = "MetinKa49194941"  # Example user_id
tweets_by_user = list(tweets_collection.find({'user.screen_name': user_id}))
print("Tweets by user:", tweets_by_user)
# Out:
# Tweets by user: [{'_id': ObjectId('66256f5becffc84c2646b97c'), 'tweet_id': 1249404589624958979, 'text': 'Waiting for the evacuation, there are\n\n✅780 babies\n✅2,500 children\n✅Thousands of political prisoners\n✅1,333 Patients\n✅457 Severe patients\n\nLet these people be evacuated before they are infected by corona virus.\n\n#COVID19InTurkeysPrisons https://t.co/27PF0A1NZR', 'hashtags': ['COVID19InTurkeysPrisons'], 'user': {'user_id': 1245408169456807936, 'name': 'Metin Kara', 'screen_name': 'MetinKa49194941'}, 'created_at': datetime.datetime(2020, 4, 12, 18, 30, 41)}, {'_id': ObjectId('66256f5becffc84c2646ba2e'), 'tweet_id': 1249404645258256387, 'text': 'Sanchez-Amor EP Rapporteur for Turkey:\n\'\' Due to the corona virus,the Turkish government\'s plan to bring amnesty is positive.\n\nIt\'s time to release hundreds of journalists, academics, lawyers and human rights defenders who have been unjustly arrested. "\n\n#COVID19InTurkeysPrisons', 'hashtags': ['COVID19InTurkeysPrisons'], 'user': {'user_id': 1245408169456807936, 'name': 'Metin Kara', 'screen_name': 'MetinKa49194941'}, 'created_at': datetime.datetime(2020, 4, 12, 18, 30, 54)}, {'_id': ObjectId('66256f5becffc84c2646bbb8'), 'tweet_id': 1249404751613251584, 'text': 'Waiting for the evacuation, there are\n- 780 babies\n- 2,500 children\n- Thousands of political prisoners\n- 1,333 Patients\n- 457 Severe patients\nLet these people be evacuated before they are infected by corona virus.\n#COVID19InTurkeysPrisons https://t.co/0AuWNZrwB2', 'hashtags': ['COVID19InTurkeysPrisons'], 'user': {'user_id': 1245408169456807936, 'name': 'Metin Kara', 'screen_name': 'MetinKa49194941'}, 'created_at': datetime.datetime(2020, 4, 12, 18, 31, 20)}]
