# %% [markdown]
# Pagination: Incorporated page and per_page arguments to control the output. Queries now compute the offset based on the page number and items per page.
# Timestamp Filtering: Added optional start_time and end_time parameters to filter results within a specific time range.
# Cache Efficiency: Included page number in the cache key to cache each page of results separately, enhancing cache relevance and utility.

# %%
# %run './DatabaseConnection_Sarthak.ipynb'
import time
from dateutil import parser
from pprint import pprint

# Convert string dates to MongoDB datetime objects
def parse_dates(start, end):
    if start and end:
        try:
            return {'$gte': parser.parse(start), '$lte': parser.parse(end)}
        except Exception as e:
            print(f"Error parsing dates: {e}")
    return {}

def perform_search(query_type, query, page=1, per_page=10, start_time=None, end_time=None):
    cache_key = f"{query_type}:{query}:{page}"
    start_cache_time = time.time() 
    cache_result = cache.get(cache_key)
    end_cache_time = time.time()
    if cache_result:
        elapsed_time = end_cache_time - start_cache_time
        print(f"Cache hit for {query}, fetched in {elapsed_time:.2f} seconds")
        return cache_result

    print(f"Cache miss for {query}")
    search_start_time = time.time()

    date_filter = parse_dates(start_time, end_time)
    result = []
    if query_type == 'user':
        user_query = """
            SELECT * FROM Users WHERE screen_name LIKE %s 
            ORDER BY followers_count DESC LIMIT %s, %s
        """
        offset = (page - 1) * per_page
        user_data = mysql_query(user_query, (f"%{query}%", offset, per_page))
        
        # Extract screen names to use in the MongoDB query
        screen_names = [user['screen_name'] for user in user_data]

        # Create a MongoDB query using the `$in` operator
        tweet_query = {
            'user.screen_name': {'$in': screen_names},
            **({} if not start_time and not end_time else {'created_at': {'$gte': start_time, '$lte': end_time}})
        }
        tweets = mongo_query(tweet_query, 'favorite_count', 10 * len(screen_names))  # Assuming you want top 10 tweets per user

        # Map tweets back to users
        for user in user_data:
            user['tweets'] = [tweet for tweet in tweets if tweet['user']['screen_name'] == user['screen_name']]
            result.append(user)

    elif query_type == 'text':
        text_query = {'$text': {'$search': query}, **date_filter}
        result = mongo_query(text_query, 'favorite_count', per_page, page)

    elif query_type == 'hashtag':
        hashtag_query = {'hashtags': query, **date_filter}
        result = mongo_query(hashtag_query, 'favorite_count', per_page, page)

    search_end_time = time.time()
    search_duration = search_end_time - search_start_time
    print(f"Search completed in {search_duration:.2f} seconds")
    cache.put(cache_key, result)
    return result

# Function to get top 10 users based on follower count
def top_10_users():
    user_query = "SELECT * FROM Users ORDER BY followers_count DESC LIMIT 10"
    return mysql_query(user_query, ())

# Function to get top 10 tweets based on favorite count
def top_10_tweets():
    tweet_query = [{'$project': {'tweet_id': 1, 'text': 1, 'favorite_count': 1}},
                   {'$sort': {'favorite_count': -1}},
                   {'$limit': 10}]
    return mongo_aggregate(tweet_query)

# Function for drill-down on tweet metadata from MySQL
def tweet_metadata(tweet_id):
    tweet_query = "SELECT * FROM Tweets WHERE tweet_id = %s"
    return mysql_query(tweet_query, (tweet_id,))

# Function for drill-down on user activity based on screen name
def user_activity(screen_name, limit=10):
    user_query = "SELECT * FROM Users WHERE screen_name = %s"
    user_data = mysql_query(user_query, (screen_name,))
    
    tweet_query = {
        'user.screen_name': screen_name
    }
    user_data['tweets'] = mongo_query(tweet_query, 'favorite_count', limit)
    
    return user_data

# %%
#cache.restore()

# %%
# Example search by text for "CovidinIndia"
search_results_text = perform_search(
    query_type='text', 
    query='CoronaVirus' 
)
print("Text Search Results:")
pprint(search_results_text)
# Out:
# Cache miss for CoronaVirus
# Search completed in 0.57 seconds
# Text Search Results:
# [{'_id': ObjectId('6628685b57e2ad708cc33802'),
#   'created_at': datetime.datetime(2020, 4, 25, 14, 39, 32),
#   'favorite_count': 331618,
#   'hashtags': [],
#   'retweet_count': 119601,
#   'text': 'This is Dr. Usama Riaz. He spent past weeks screening and treating '
#           'patients with Corona Virus in Pakistan. \n'
#           '\n'
#           'He knew there was no PPE. He persisted anyways.\n'
#           '\n'
#           'Today he lost his own battle with coronavirus but he gave life and '
#           'hope to so many more. \n'
#           '\n'
#           'KNOW HIS NAME 😭❤ https://t.co/flSwhLCPmx',
#   'tweet_id': 1254057458852679680,
#   'user': {'name': 'ℑ𝔤𝔤𝔶',
#            'screen_name': 'ialixooxo',
#            'user_id': 936625453594488832}},
#  {'_id': ObjectId('6628551f57e2ad708cc2213a'),
#   'created_at': datetime.datetime(2020, 4, 25, 12, 58, 7),
#   'favorite_count': 165110,
#   'hashtags': [],
#   'retweet_count': 18093,
#   'text': 'O mundo inteiro está unido contra o coronavírus. No Brasil, temos '
#           'de lutar contra o corona e o vírus do autoritarismo. É mais '
#           'trabalhoso, mas venceremos. Em nome da Câmara dos Deputados, '
#           'repudio todo e qualquer ato que defenda a ditadura, atentando '
#           'contra a Constituição.',
#   'tweet_id': 1254031937775247363,
#   'user': {'name': 'M. Carmo Freitas',
#            'screen_name': 'carmemk2',
#            'user_id': 2421849649}},
#  {'_id': ObjectId('6628617457e2ad708cc2d477'),
#   'created_at': datetime.datetime(2020, 4, 25, 14, 3, 54),
#   'favorite_count': 112230,
#   'hashtags': [],
#   'retweet_count': 29556,
#   'text': 'coronavirus\n'
#           'coronavir\n'
#           'corona\n'
#           'coronao \n'
#           'coronao coronao\n'
#           'coronao coronao now now now',
#   'tweet_id': 1254048493347287046,
#   'user': {'name': 'ピンキー小松P',
#            'screen_name': 'pinky9moyashi',
#            'user_id': 4431803772}},
#  {'_id': ObjectId('66285fc557e2ad708cc2bbfc'),
#   'created_at': datetime.datetime(2020, 4, 25, 13, 55, 6),
#   'favorite_count': 96367,
#   'hashtags': [],
#   'retweet_count': 29424,
#   'text': "“If I get corona, I get corona. At the end of the day, I'm not "
#           'gonna let it stop me from partying”: Spring breakers are still '
#           'flocking to Miami, despite coronavirus warnings. '
#           'https://t.co/KoYKI8zNDH https://t.co/rfPfea1LrC',
#   'tweet_id': 1254046279031611392,
#   'user': {'name': 'ฅ^•ﻌ•^ฅ', 'screen_name': 'Yalpacaa', 'user_id': 323688490}},
#  {'_id': ObjectId('66285d1f57e2ad708cc29598'),
#   'created_at': datetime.datetime(2020, 4, 25, 13, 41, 11),
#   'favorite_count': 48464,
#   'hashtags': ['coronavirus'],
#   'retweet_count': 16222,
#   'text': 'The Corona Virus is an extremely serious threat to our people and '
#           'our economy. My sense is the government is not taking this threat '
#           'seriously. \n'
#           '\n'
#           'Timely action is critical.\n'
#           '\n'
#           '#coronavirus \n'
#           '\n'
#           'https://t.co/bspz4l1tFM',
#   'tweet_id': 1254042774946500610,
#   'user': {'name': 'Deeksha Mankar',
#            'screen_name': 'DeekshaMankar',
#            'user_id': 2916676662}},
#  {'_id': ObjectId('66285fb457e2ad708cc2baff'),
#   'created_at': datetime.datetime(2020, 4, 25, 13, 54, 45),
#   'favorite_count': 48433,
#   'hashtags': ['coronavirus'],
#   'retweet_count': 16223,
#   'text': 'The Corona Virus is an extremely serious threat to our people and '
#           'our economy. My sense is the government is not taking this threat '
#           'seriously. \n'
#           '\n'
#           'Timely action is critical.\n'
#           '\n'
#           '#coronavirus \n'
#           '\n'
#           'https://t.co/bspz4l1tFM',
#   'tweet_id': 1254046192473911298,
#   'user': {'name': 'Inamul patel',
#            'screen_name': 'Inamul01892658',
#            'user_id': 873670907423805440}},
#  {'_id': ObjectId('66284c0e57e2ad708cc19e0c'),
#   'created_at': datetime.datetime(2020, 4, 12, 18, 36, 52),
#   'favorite_count': 47944,
#   'hashtags': ['coronavirus'],
#   'retweet_count': 15983,
#   'text': 'The Corona Virus is an extremely serious threat to our people and '
#           'our economy. My sense is the government is not taking this threat '
#           'seriously. \n'
#           '\n'
#           'Timely action is critical.\n'
#           '\n'
#           '#coronavirus \n'
#           '\n'
#           'https://t.co/bspz4l1tFM',
#   'tweet_id': 1249406144558305280,
#   'user': {'name': 'India against Hate',
#            'screen_name': 'BetterSociety13',
#            'user_id': 1156329998342426624}},
#  {'_id': ObjectId('6628497357e2ad708cc17c8e'),
#   'created_at': datetime.datetime(2020, 4, 12, 18, 27, 27),
#   'favorite_count': 25064,
#   'hashtags': [],
#   'retweet_count': 13482,
#   'text': 'In this clip, Trump:\n'
#           '1. Denies WHO\'s coronavirus death rate based on “hunch"\n'
#           '2. Calls coronavirus "corona flu"\n'
#           "3. Suggests it's fine for people w/ Covid-19 to go to work\n"
#           '4. Compares coronavirus to "the regular flu," indicating he '
#           "doesn't get the difference https://t.co/uC9c03zX31",
#   'tweet_id': 1249403774151659521,
#   'user': {'name': 'Wiltac',
#            'screen_name': 'WiredRoots101',
#            'user_id': 3294456317}},
#  {'_id': ObjectId('66285f2457e2ad708cc2b2d4'),
#   'created_at': datetime.datetime(2020, 4, 25, 13, 51, 54),
#   'favorite_count': 19602,
#   'hashtags': [],
#   'retweet_count': 13720,
#   'text': "Unfortunately we've lost a few followers due to sharing this "
#           "article about the government's failings regarding Coronavirus\n"
#           '\n'
#           "This is not about politics, it's about the many lives that are at "
#           'stake, and ignoring it helps no one\n'
#           '\n'
#           'Please follow and RT if you remain right behind us',
#   'tweet_id': 1254045472928530432,
#   'user': {'name': 'Lolli Pops',
#            'screen_name': 'TheKojakComplex',
#            'user_id': 549290132}},
#  {'_id': ObjectId('662857c057e2ad708cc247b3'),
#   'created_at': datetime.datetime(2020, 4, 25, 13, 12, 29),
#   'favorite_count': 19599,
#   'hashtags': [],
#   'retweet_count': 13719,
#   'text': "Unfortunately we've lost a few followers due to sharing this "
#           "article about the government's failings regarding Coronavirus\n"
#           '\n'
#           "This is not about politics, it's about the many lives that are at "
#           'stake, and ignoring it helps no one\n'
#           '\n'
#           'Please follow and RT if you remain right behind us '
#           'https://t.co/ka2eC3U7t4',
#   'tweet_id': 1254035553072418817,
#   'user': {'name': 'Rabbit Away',
#            'screen_name': 'rabbitaway',
#            'user_id': 1691215087}}]

# %%
# Example search by hashtag for "COVID19InTurkeysPrisons"
search_results_hashtag = perform_search(
    query_type='hashtag', 
    query='COVID19InTurkeysPrisons'
)
print("\nHashtag Search Results:")
pprint(search_results_hashtag)
# Out:
# Cache miss for COVID19InTurkeysPrisons
# INFO:root:MongoDB connection closed.
# Search completed in 0.53 seconds
#
# Hashtag Search Results:
# [{'_id': ObjectId('66284e5b57e2ad708cc1bf7a'),
#   'created_at': datetime.datetime(2020, 4, 12, 18, 46, 20),
#   'favorite_count': 118,
#   'hashtags': ['COVID19InTurkeysPrisons'],
#   'retweet_count': 208,
#   'text': 'Waiting for the evacuation, there are\n'
#           '\n'
#           '✅780 babies\n'
#           '✅2,500 children\n'
#           '✅Thousands of political prisoners\n'
#           '✅1,333 Patients\n'
#           '✅457 Severe patients\n'
#           '\n'
#           'Let these people be evacuated before they are infected by corona '
#           'virus.\n'
#           '\n'
#           '#COVID19InTurkeysPrisons https://t.co/27PF0A1NZR',
#   'tweet_id': 1249408528730767367,
#   'user': {'name': 'Nihal Sema',
#            'screen_name': 'NihalSema1',
#            'user_id': 825077506441097216}},
#  {'_id': ObjectId('66284e6957e2ad708cc1c047'),
#   'created_at': datetime.datetime(2020, 4, 12, 18, 46, 34),
#   'favorite_count': 118,
#   'hashtags': ['COVID19InTurkeysPrisons'],
#   'retweet_count': 209,
#   'text': 'Waiting for the evacuation, there are\n'
#           '\n'
#           '✅780 babies\n'
#           '✅2,500 children\n'
#           '✅Thousands of political prisoners\n'
#           '✅1,333 Patients\n'
#           '✅457 Severe patients\n'
#           '\n'
#           'Let these people be evacuated before they are infected by corona '
#           'virus.\n'
#           '\n'
#           '#COVID19InTurkeysPrisons https://t.co/27PF0A1NZR',
#   'tweet_id': 1249408587035750403,
#   'user': {'name': '🇹🇷🇽🇰RabiaSahin🇦🇱🇬🇧',
#            'screen_name': 'hafsahajrullahi',
#            'user_id': 933063031109636096}},
#  {'_id': ObjectId('66284e7e57e2ad708cc1c17f'),
#   'created_at': datetime.datetime(2020, 4, 12, 18, 46, 55),
#   'favorite_count': 118,
#   'hashtags': ['COVID19InTurkeysPrisons'],
#   'retweet_count': 210,
#   'text': 'Waiting for the evacuation, there are\n'
#           '\n'
#           '✅780 babies\n'
#           '✅2,500 children\n'
#           '✅Thousands of political prisoners\n'
#           '✅1,333 Patients\n'
#           '✅457 Severe patients\n'
#           '\n'
#           'Let these people be evacuated before they are infected by corona '
#           'virus.\n'
#           '\n'
#           '#COVID19InTurkeysPrisons https://t.co/27PF0A1NZR',
#   'tweet_id': 1249408676055703552,
#   'user': {'name': 'zeylif',
#            'screen_name': 'bdikmen01',
#            'user_id': 3497082852}},
#  {'_id': ObjectId('66284e1357e2ad708cc1bb66'),
#   'created_at': datetime.datetime(2020, 4, 12, 18, 45, 9),
#   'favorite_count': 117,
#   'hashtags': ['COVID19InTurkeysPrisons'],
#   'retweet_count': 206,
#   'text': 'Waiting for the evacuation, there are\n'
#           '\n'
#           '✅780 babies\n'
#           '✅2,500 children\n'
#           '✅Thousands of political prisoners\n'
#           '✅1,333 Patients\n'
#           '✅457 Severe patients\n'
#           '\n'
#           'Let these people be evacuated before they are infected by corona '
#           'virus.\n'
#           '\n'
#           '#COVID19InTurkeysPrisons https://t.co/27PF0A1NZR',
#   'tweet_id': 1249408229047762947,
#   'user': {'name': 'eski öğretmen',
#            'screen_name': 'fenbilgis',
#            'user_id': 891941825589764096}},
#  {'_id': ObjectId('66284e4157e2ad708cc1be01'),
#   'created_at': datetime.datetime(2020, 4, 12, 18, 45, 55),
#   'favorite_count': 117,
#   'hashtags': ['COVID19InTurkeysPrisons'],
#   'retweet_count': 207,
#   'text': 'Waiting for the evacuation, there are\n'
#           '\n'
#           '✅780 babies\n'
#           '✅2,500 children\n'
#           '✅Thousands of political prisoners\n'
#           '✅1,333 Patients\n'
#           '✅457 Severe patients\n'
#           '\n'
#           'Let these people be evacuated before they are infected by corona '
#           'virus.\n'
#           '\n'
#           '#COVID19InTurkeysPrisons https://t.co/27PF0A1NZR',
#   'tweet_id': 1249408423478857728,
#   'user': {'name': 'Yenibahar',
#            'screen_name': 'Yenibahar21',
#            'user_id': 1246430262940045314}},
#  {'_id': ObjectId('66284df857e2ad708cc1b9e6'),
#   'created_at': datetime.datetime(2020, 4, 12, 18, 44, 42),
#   'favorite_count': 115,
#   'hashtags': ['COVID19InTurkeysPrisons'],
#   'retweet_count': 205,
#   'text': 'Waiting for the evacuation, there are\n'
#           '\n'
#           '✅780 babies\n'
#           '✅2,500 children\n'
#           '✅Thousands of political prisoners\n'
#           '✅1,333 Patients\n'
#           '✅457 Severe patients\n'
#           '\n'
#           'Let these people be evacuated before they are infected by corona '
#           'virus.\n'
#           '\n'
#           '#COVID19InTurkeysPrisons https://t.co/27PF0A1NZR',
#   'tweet_id': 1249408117949059076,
#   'user': {'name': 'MARİA NİTO',
#            'screen_name': 'maria_nito4',
#            'user_id': 1243510213518471174}},
#  {'_id': ObjectId('66284dcc57e2ad708cc1b76a'),
#   'created_at': datetime.datetime(2020, 4, 12, 18, 43, 59),
#   'favorite_count': 114,
#   'hashtags': ['COVID19InTurkeysPrisons'],
#   'retweet_count': 204,
#   'text': 'Waiting for the evacuation, there are\n'
#           '\n'
#           '✅780 babies\n'
#           '✅2,500 children\n'
#           '✅Thousands of political prisoners\n'
#           '✅1,333 Patients\n'
#           '✅457 Severe patients\n'
#           '\n'
#           'Let these people be evacuated before they are infected by corona '
#           'virus.\n'
#           '\n'
#           '#COVID19InTurkeysPrisons https://t.co/27PF0A1NZR',
#   'tweet_id': 1249407936125964290,
#   'user': {'name': 'freedom',
#            'screen_name': 'freedom63243649',
#            'user_id': 1187973219845922817}},
#  {'_id': ObjectId('66284dc957e2ad708cc1b73b'),
#   'created_at': datetime.datetime(2020, 4, 12, 18, 43, 56),
#   'favorite_count': 113,
#   'hashtags': ['COVID19InTurkeysPrisons'],
#   'retweet_count': 203,
#   'text': 'Waiting for the evacuation, there are\n'
#           '\n'
#           '✅780 babies\n'
#           '✅2,500 children\n'
#           '✅Thousands of political prisoners\n'
#           '✅1,333 Patients\n'
#           '✅457 Severe patients\n'
#           '\n'
#           'Let these people be evacuated before they are infected by corona '
#           'virus.\n'
#           '\n'
#           '#COVID19InTurkeysPrisons https://t.co/27PF0A1NZR',
#   'tweet_id': 1249407922473504770,
#   'user': {'name': 'Arda DERİN(GT)',
#            'screen_name': 'ArdaDERN3',
#            'user_id': 1241051678352257027}},
#  {'_id': ObjectId('66284dbc57e2ad708cc1b670'),
#   'created_at': datetime.datetime(2020, 4, 12, 18, 43, 41),
#   'favorite_count': 113,
#   'hashtags': ['COVID19InTurkeysPrisons'],
#   'retweet_count': 202,
#   'text': 'Waiting for the evacuation, there are\n'
#           '\n'
#           '✅780 babies\n'
#           '✅2,500 children\n'
#           '✅Thousands of political prisoners\n'
#           '✅1,333 Patients\n'
#           '✅457 Severe patients\n'
#           '\n'
#           'Let these people be evacuated before they are infected by corona '
#           'virus.\n'
#           '\n'
#           '#COVID19InTurkeysPrisons https://t.co/27PF0A1NZR',
#   'tweet_id': 1249407860724895744,
#   'user': {'name': 'SUDE',
#            'screen_name': 'Sude04236628',
#            'user_id': 1243271098634063875}},
#  {'_id': ObjectId('66284d3857e2ad708cc1af0b'),
#   'created_at': datetime.datetime(2020, 4, 12, 18, 41, 33),
#   'favorite_count': 112,
#   'hashtags': ['COVID19InTurkeysPrisons'],
#   'retweet_count': 199,
#   'text': 'Waiting for the evacuation, there are\n'
#           '\n'
#           '✅780 babies\n'
#           '✅2,500 children\n'
#           '✅Thousands of political prisoners\n'
#           '✅1,333 Patients\n'
#           '✅457 Severe patients\n'
#           '\n'
#           'Let these people be evacuated before they are infected by corona '
#           'virus.\n'
#           '\n'
#           '#COVID19InTurkeysPrisons https://t.co/27PF0A1NZR',
#   'tweet_id': 1249407325653413888,
#   'user': {'name': 'Freedom Seekers',
#            'screen_name': 'FrdmSkrs',
#            'user_id': 948964975472791553}}]

# %%
# Example search by user for "Deeksha"
search_results_user = perform_search(
    query_type='user', 
    query='Deeksha'
)
print("\nUser Search Results:")
pprint(search_results_user)
# Out:
# Cache miss for Deeksha
# INFO:root:MongoDB connection closed.
# Search completed in 0.89 seconds
#
# User Search Results:
# [{'created_at': datetime.datetime(2018, 8, 5, 9, 10, 10),
#   'followers_count': 2104,
#   'friends_count': 262,
#   'location': 'India',
#   'name': 'Deeksha Thakurr',
#   'screen_name': 'thakur_deekshaa',
#   'statuses_count': 82692,
#   'tweets': [{'_id': ObjectId('66285b4c57e2ad708cc27b31'),
#               'created_at': datetime.datetime(2020, 4, 25, 13, 31, 16),
#               'favorite_count': 172,
#               'hashtags': [],
#               'retweet_count': 80,
#               'text': 'If that’s how they are following lockdown/social  '
#                       'distancing then Mumbai is sitting on Corona bomb.\n'
#                       'This is Mumbra Market yesterday afternoon👇 '
#                       'https://t.co/LGuPJjIua5',
#               'tweet_id': 1254040278710829061,
#               'user': {'name': 'Deeksha Thakurr',
#                        'screen_name': 'thakur_deekshaa',
#                        'user_id': 1026032604124868608}}],
#   'user_id': 1026032604124868608},
#  {'created_at': datetime.datetime(2016, 9, 17, 10, 19, 54),
#   'followers_count': 252,
#   'friends_count': 848,
#   'location': 'Lincoln, England',
#   'name': 'Deeksha Teri',
#   'screen_name': 'DeekshaTeri',
#   'statuses_count': 3312,
#   'tweets': [{'_id': ObjectId('662857b457e2ad708cc246f7'),
#               'created_at': datetime.datetime(2020, 4, 25, 13, 12, 11),
#               'favorite_count': 1945,
#               'hashtags': [],
#               'retweet_count': 323,
#               'text': '"Go Corona Go" sounds positively scientific &amp; peer '
#                       'reviewed in comparison to drinking disinfectants.',
#               'tweet_id': 1254035477323104256,
#               'user': {'name': 'Deeksha Teri',
#                        'screen_name': 'DeekshaTeri',
#                        'user_id': 777089689853366272}}],
#   'user_id': 777089689853366272},
#  {'created_at': datetime.datetime(2014, 12, 2, 15, 1, 4),
#   'followers_count': 13,
#   'friends_count': 15,
#   'location': 'Mumbai',
#   'name': 'Deeksha Mankar',
#   'screen_name': 'DeekshaMankar',
#   'statuses_count': 408,
#   'tweets': [{'_id': ObjectId('66285d1f57e2ad708cc29598'),
#               'created_at': datetime.datetime(2020, 4, 25, 13, 41, 11),
#               'favorite_count': 48464,
#               'hashtags': ['coronavirus'],
#               'retweet_count': 16222,
#               'text': 'The Corona Virus is an extremely serious threat to our '
#                       'people and our economy. My sense is the government is '
#                       'not taking this threat seriously. \n'
#                       '\n'
#                       'Timely action is critical.\n'
#                       '\n'
#                       '#coronavirus \n'
#                       '\n'
#                       'https://t.co/bspz4l1tFM',
#               'tweet_id': 1254042774946500610,
#               'user': {'name': 'Deeksha Mankar',
#                        'screen_name': 'DeekshaMankar',
#                        'user_id': 2916676662}}],
#   'user_id': 2916676662}]

# %%
cache.print_cache()
# Out:
# Cache contents:
# Key: hashtag:Covid19:1, Data: [{'_id': ObjectId('66284b1357e2ad708cc18fe8'), 'tweet_id': 1249405207156424704, 'text': 'राबी की फसल खेतों में तैयार खड़ी है लेकिन #Covid19 लॉक्डाउन में कटाई का काम मुश्किल है।सैकड़ों किसानों की जीविका ख़तरे में है।देश के अन्नदाता किसान आज इस संकट में दोहरी मुसीबत में हैं। कटाई के लिए सुरक्षित तरीक़े से लॉक्डाउन में ढील देना एकमात्र रास्ता है।\nhttps://t.co/fOc2cUA10D', 'hashtags': ['Covid19'], 'user': {'user_id': 3315155226, 'name': 'Dr.Sanjeev Rajpurohit', 'screen_name': 'DrSanjeevRajp4'}, 'retweet_count': 9225, 'favorite_count': 43655, 'created_at': datetime.datetime(2020, 4, 12, 18, 33, 8)}, {'_id': ObjectId('66284c2957e2ad708cc19f92'), 'tweet_id': 1249406245645307905, 'text': 'राबी की फसल खेतों में तैयार खड़ी है लेकिन #Covid19 लॉक्डाउन में कटाई का काम मुश्किल है।सैकड़ों किसानों की जीविका ख़तरे में है।देश के अन्नदाता किसान आज इस संकट में दोहरी मुसीबत में हैं। कटाई के लिए सुरक्षित तरीक़े से लॉक्डाउन में ढील देना एकमात्र रास्ता है।\nhttps://t.co/fOc2cUA10D', 'hashtags': ['Covid19'], 'user': {'user_id': 816315038671716352, 'name': 'Sourabh_Nareti 🇮🇳', 'screen_name': 'SourabhNareti'}, 'retweet_count': 9225, 'favorite_count': 43636, 'created_at': datetime.datetime(2020, 4, 12, 18, 37, 16)}, {'_id': ObjectId('662860c757e2ad708cc2caa1'), 'tweet_id': 1254047614401523712, 'text': 'Story of a medical officer of #Gujarat\nI am Rupal,a medical officer working for @AmdavadAMC for #Covid19. I started feeling sick but was kept on duty when I was demanding checkup. I have now been detected #corona positive &amp; am being treated as trash at  #SVP hospital #Gujarat 1/2 https://t.co/felcqBlrN5', 'hashtags': ['Gujarat', 'Covid19', 'corona', 'SVP', 'Gujarat'], 'user': {'user_id': 1214721641432764417, 'name': 'mona', 'screen_name': 'im__mona'}, 'retweet_count': 1793, 'favorite_count': 2764, 'created_at': datetime.datetime(2020, 4, 25, 14, 0, 25)}, {'_id': ObjectId('66285f1457e2ad708cc2b1f6'), 'tweet_id': 1254045396135022594, 'text': 'Story of a medical officer of #Gujarat\nI am Rupal,a medical officer working for @AmdavadAMC for #Covid19. I started feeling sick but was kept on duty when I was demanding checkup. I have now been detected #corona positive &amp; am being treated as trash at  #SVP hospital #Gujarat 1/2 https://t.co/felcqBlrN5', 'hashtags': ['Gujarat', 'Covid19', 'corona', 'SVP', 'Gujarat'], 'user': {'user_id': 1222892614451527680, 'name': 'Shadab', 'screen_name': 'Shadab16562825'}, 'retweet_count': 1792, 'favorite_count': 2763, 'created_at': datetime.datetime(2020, 4, 25, 13, 51, 36)}, {'_id': ObjectId('66285de957e2ad708cc2a10a'), 'tweet_id': 1254043833282813953, 'text': 'Story of a medical officer of #Gujarat\nI am Rupal,a medical officer working for @AmdavadAMC for #Covid19. I started feeling sick but was kept on duty when I was demanding checkup. I have now been detected #corona positive &amp; am being treated as trash at  #SVP hospital #Gujarat 1/2 https://t.co/felcqBlrN5', 'hashtags': ['Gujarat', 'Covid19', 'corona', 'SVP', 'Gujarat'], 'user': {'user_id': 138699088, 'name': 'Akhilesh Kumar', 'screen_name': 'akhileshankhwar'}, 'retweet_count': 1791, 'favorite_count': 2762, 'created_at': datetime.datetime(2020, 4, 25, 13, 45, 23)}, {'_id': ObjectId('662860bb57e2ad708cc2ca01'), 'tweet_id': 1254047565152051202, 'text': 'To serve the people of Chhattisgarh better amidst this emergency and to be better prepared to combat Corona Crisis, the Chhattisgarh govt. has taken over RIMS, Raipur. \n\nChhattisgarh will leave no stone unturned in fight against #Covid19!', 'hashtags': ['Covid19'], 'user': {'user_id': 3240124281, 'name': 'Irfan Madni', 'screen_name': 'IrfanMadniMP'}, 'retweet_count': 369, 'favorite_count': 1331, 'created_at': datetime.datetime(2020, 4, 25, 14, 0, 13)}, {'_id': ObjectId('6628519357e2ad708cc1eddf'), 'tweet_id': 1254026977608175622, 'text': 'I am Rupal,medical officer working for @AmdavadAMC for #Covid19.I started feeling sick but was kept on duty when I was demanding checkup &amp; Now  ...
# Key: user:Sarjesh:1, Data: [{'user_id': 1254056440592871425, 'name': 'Sarjesh', 'screen_name': 'Sarjesh9', 'location': None, 'followers_count': 0, 'friends_count': 13, 'statuses_count': 2, 'created_at': datetime.datetime(2020, 4, 25, 14, 35, 48), 'tweets': [{'_id': ObjectId('6628691157e2ad708cc34241'), 'tweet_id': 1254058338284826625, 'text': '@RajatSharmaLive @indiatvnews Lockdown ka palan karte hue India ko bachana corona virus', 'hashtags': [], 'user': {'user_id': 1254056440592871425, 'name': 'Sarjesh', 'screen_name': 'Sarjesh9'}, 'retweet_count': 0, 'favorite_count': 0, 'created_at': datetime.datetime(2020, 4, 25, 14, 43, 1)}]}], Timestamp: 1713928313.146549, Age: 990.66 seconds
# Key: text:Covid19:1, Data: [{'_id': ObjectId('66284b1357e2ad708cc18fe8'), 'tweet_id': 1249405207156424704, 'text': 'राबी की फसल खेतों में तैयार खड़ी है लेकिन #Covid19 लॉक्डाउन में कटाई का काम मुश्किल है।सैकड़ों किसानों की जीविका ख़तरे में है।देश के अन्नदाता किसान आज इस संकट में दोहरी मुसीबत में हैं। कटाई के लिए सुरक्षित तरीक़े से लॉक्डाउन में ढील देना एकमात्र रास्ता है।\nhttps://t.co/fOc2cUA10D', 'hashtags': ['Covid19'], 'user': {'user_id': 3315155226, 'name': 'Dr.Sanjeev Rajpurohit', 'screen_name': 'DrSanjeevRajp4'}, 'retweet_count': 9225, 'favorite_count': 43655, 'created_at': datetime.datetime(2020, 4, 12, 18, 33, 8)}, {'_id': ObjectId('66284c2957e2ad708cc19f92'), 'tweet_id': 1249406245645307905, 'text': 'राबी की फसल खेतों में तैयार खड़ी है लेकिन #Covid19 लॉक्डाउन में कटाई का काम मुश्किल है।सैकड़ों किसानों की जीविका ख़तरे में है।देश के अन्नदाता किसान आज इस संकट में दोहरी मुसीबत में हैं। कटाई के लिए सुरक्षित तरीक़े से लॉक्डाउन में ढील देना एकमात्र रास्ता है।\nhttps://t.co/fOc2cUA10D', 'hashtags': ['Covid19'], 'user': {'user_id': 816315038671716352, 'name': 'Sourabh_Nareti 🇮🇳', 'screen_name': 'SourabhNareti'}, 'retweet_count': 9225, 'favorite_count': 43636, 'created_at': datetime.datetime(2020, 4, 12, 18, 37, 16)}, {'_id': ObjectId('6628649157e2ad708cc30112'), 'tweet_id': 1254052582663880707, 'text': 'If you’ve recovered from COVID19, you are a Corona warrior. We need an army of such warriors to overcome this invisible enemy. Your blood contains the bullets that can kill the virus. Please donate your blood, so others, especially the serious ones can recover. Sign up now🙏', 'hashtags': [], 'user': {'user_id': 1254051527624396801, 'name': 'Suraj Kumar', 'screen_name': 'SurajKu99374082'}, 'retweet_count': 4148, 'favorite_count': 35886, 'created_at': datetime.datetime(2020, 4, 25, 14, 20, 9)}, {'_id': ObjectId('662851ea57e2ad708cc1f2c4'), 'tweet_id': 1254027478953271297, 'text': 'If you’ve recovered from COVID19, you are a Corona warrior. We need an army of such warriors to overcome this invisible enemy. Your blood contains the bullets that can kill the virus. Please donate your blood, so others, especially the serious ones can recover. Sign up now🙏', 'hashtags': [], 'user': {'user_id': 835192431159160837, 'name': 'K3DB2', 'screen_name': 'Kkb_kdb'}, 'retweet_count': 4147, 'favorite_count': 35877, 'created_at': datetime.datetime(2020, 4, 25, 12, 40, 24)}, {'_id': ObjectId('66284ecb57e2ad708cc1c5db'), 'tweet_id': 1254022883443011584, 'text': 'Let’s respect and honour our Doctors and medical staff..\nJust convey your heartfelt gratitude to all the Doctors, Nurses,paramedical staff and other frontline workers ,who are taking care of Covid19 patients-', 'hashtags': [], 'user': {'user_id': 1252565481258655746, 'name': 'Pspk Follower', 'screen_name': 'pspksasi'}, 'retweet_count': 2640, 'favorite_count': 10334, 'created_at': datetime.datetime(2020, 4, 25, 12, 22, 8)}, {'_id': ObjectId('66285e4157e2ad708cc2a603'), 'tweet_id': 1254044280139722752, 'text': 'Happening Now in San Diego in response to closing walking trails and beaches. #COVID19 #corona #encinitas #sandiego https://t.co/ukmyMbx2yq', 'hashtags': ['COVID19', 'corona', 'encinitas', 'sandiego'], 'user': {'user_id': 136862547, 'name': 'Shirley Fields 🍷', 'screen_name': 'Queenyati'}, 'retweet_count': 4606, 'favorite_count': 8097, 'created_at': datetime.datetime(2020, 4, 25, 13, 47, 10)}, {'_id': ObjectId('6628550e57e2ad708cc22043'), 'tweet_id': 1254031840714711045, 'text': 'a neighborhood in italy singinging ‘little things’ by one direction while they’re lockdown due to corona virus issue \n\n#COVIDー19 https://t.co/Zjnm5mLzFN', 'hashtags': ['COVIDー19'], 'user': {'user_id': 1170675525896900608, 'name': 'nash was @captivatebesson', 'screen_name': 'petrichorspace'}, 'retweet_count': 1637, 'favorite_count': 5827, 'created_at': datetime.datetime(2020, 4, 25, 12, 57, 44)}, {'_id': ObjectId('6628562057e2ad708cc22fec'), 'tweet_id': 1254033350479626241, 'text': '...because hunger cannot wait ...
# Key: text:CovidinIndia:1, Data: [], Timestamp: 1713929259.8656619, Age: 43.94 seconds
# Key: text:CoronaVirus:1, Data: [{'_id': ObjectId('6628685b57e2ad708cc33802'), 'tweet_id': 1254057458852679680, 'text': 'This is Dr. Usama Riaz. He spent past weeks screening and treating patients with Corona Virus in Pakistan. \n\nHe knew there was no PPE. He persisted anyways.\n\nToday he lost his own battle with coronavirus but he gave life and hope to so many more. \n\nKNOW HIS NAME 😭❤ https://t.co/flSwhLCPmx', 'hashtags': [], 'user': {'user_id': 936625453594488832, 'name': 'ℑ𝔤𝔤𝔶', 'screen_name': 'ialixooxo'}, 'retweet_count': 119601, 'favorite_count': 331618, 'created_at': datetime.datetime(2020, 4, 25, 14, 39, 32)}, {'_id': ObjectId('6628551f57e2ad708cc2213a'), 'tweet_id': 1254031937775247363, 'text': 'O mundo inteiro está unido contra o coronavírus. No Brasil, temos de lutar contra o corona e o vírus do autoritarismo. É mais trabalhoso, mas venceremos. Em nome da Câmara dos Deputados, repudio todo e qualquer ato que defenda a ditadura, atentando contra a Constituição.', 'hashtags': [], 'user': {'user_id': 2421849649, 'name': 'M. Carmo Freitas', 'screen_name': 'carmemk2'}, 'retweet_count': 18093, 'favorite_count': 165110, 'created_at': datetime.datetime(2020, 4, 25, 12, 58, 7)}, {'_id': ObjectId('6628617457e2ad708cc2d477'), 'tweet_id': 1254048493347287046, 'text': 'coronavirus\ncoronavir\ncorona\ncoronao \ncoronao coronao\ncoronao coronao now now now', 'hashtags': [], 'user': {'user_id': 4431803772, 'name': 'ピンキー小松P', 'screen_name': 'pinky9moyashi'}, 'retweet_count': 29556, 'favorite_count': 112230, 'created_at': datetime.datetime(2020, 4, 25, 14, 3, 54)}, {'_id': ObjectId('66285fc557e2ad708cc2bbfc'), 'tweet_id': 1254046279031611392, 'text': "“If I get corona, I get corona. At the end of the day, I'm not gonna let it stop me from partying”: Spring breakers are still flocking to Miami, despite coronavirus warnings. https://t.co/KoYKI8zNDH https://t.co/rfPfea1LrC", 'hashtags': [], 'user': {'user_id': 323688490, 'name': 'ฅ^•ﻌ•^ฅ', 'screen_name': 'Yalpacaa'}, 'retweet_count': 29424, 'favorite_count': 96367, 'created_at': datetime.datetime(2020, 4, 25, 13, 55, 6)}, {'_id': ObjectId('66285d1f57e2ad708cc29598'), 'tweet_id': 1254042774946500610, 'text': 'The Corona Virus is an extremely serious threat to our people and our economy. My sense is the government is not taking this threat seriously. \n\nTimely action is critical.\n\n#coronavirus \n\nhttps://t.co/bspz4l1tFM', 'hashtags': ['coronavirus'], 'user': {'user_id': 2916676662, 'name': 'Deeksha Mankar', 'screen_name': 'DeekshaMankar'}, 'retweet_count': 16222, 'favorite_count': 48464, 'created_at': datetime.datetime(2020, 4, 25, 13, 41, 11)}, {'_id': ObjectId('66285fb457e2ad708cc2baff'), 'tweet_id': 1254046192473911298, 'text': 'The Corona Virus is an extremely serious threat to our people and our economy. My sense is the government is not taking this threat seriously. \n\nTimely action is critical.\n\n#coronavirus \n\nhttps://t.co/bspz4l1tFM', 'hashtags': ['coronavirus'], 'user': {'user_id': 873670907423805440, 'name': 'Inamul patel', 'screen_name': 'Inamul01892658'}, 'retweet_count': 16223, 'favorite_count': 48433, 'created_at': datetime.datetime(2020, 4, 25, 13, 54, 45)}, {'_id': ObjectId('66284c0e57e2ad708cc19e0c'), 'tweet_id': 1249406144558305280, 'text': 'The Corona Virus is an extremely serious threat to our people and our economy. My sense is the government is not taking this threat seriously. \n\nTimely action is critical.\n\n#coronavirus \n\nhttps://t.co/bspz4l1tFM', 'hashtags': ['coronavirus'], 'user': {'user_id': 1156329998342426624, 'name': 'India against Hate', 'screen_name': 'BetterSociety13'}, 'retweet_count': 15983, 'favorite_count': 47944, 'created_at': datetime.datetime(2020, 4, 12, 18, 36, 52)}, {'_id': ObjectId('6628497357e2ad708cc17c8e'), 'tweet_id': 1249403774151659521, 'text': 'In this clip, Trump:\n1. Denies WHO\'s coronavirus death rate based on “hunch"\n2. Calls coronavirus "corona flu"\n3. Suggests it\'s fine for people w/ Covid-19 to go to work\n4. C ...
# Key: user:Yenibahar:1, Data: [{'user_id': 1246430262940045314, 'name': 'Yenibahar', 'screen_name': 'Yenibahar21', 'location': None, 'followers_count': 37, 'friends_count': 79, 'statuses_count': 228, 'created_at': datetime.datetime(2020, 4, 4, 13, 32, 24), 'tweets': [{'_id': ObjectId('66284e4157e2ad708cc1be01'), 'tweet_id': 1249408423478857728, 'text': 'Waiting for the evacuation, there are\n\n✅780 babies\n✅2,500 children\n✅Thousands of political prisoners\n✅1,333 Patients\n✅457 Severe patients\n\nLet these people be evacuated before they are infected by corona virus.\n\n#COVID19InTurkeysPrisons https://t.co/27PF0A1NZR', 'hashtags': ['COVID19InTurkeysPrisons'], 'user': {'user_id': 1246430262940045314, 'name': 'Yenibahar', 'screen_name': 'Yenibahar21'}, 'retweet_count': 207, 'favorite_count': 117, 'created_at': datetime.datetime(2020, 4, 12, 18, 45, 55)}, {'_id': ObjectId('66284e1057e2ad708cc1bb3d'), 'tweet_id': 1249408218507476993, 'text': 'In Turkey, there are 300 thousand prisoners and 150 thousand prison employees in prisons. Prisons are the most risky places in case of corona virüs. The lives of thousands of people are at risk.\n\n#COVID19InTurkeysPrisons', 'hashtags': ['COVID19InTurkeysPrisons'], 'user': {'user_id': 1246430262940045314, 'name': 'Yenibahar', 'screen_name': 'Yenibahar21'}, 'retweet_count': 161, 'favorite_count': 102, 'created_at': datetime.datetime(2020, 4, 12, 18, 45, 6)}, {'_id': ObjectId('66284e8d57e2ad708cc1c259'), 'tweet_id': 1249408742006931457, 'text': 'Turkey has currently a total of 1564 prisoners, including 560 seriously ill ones.\nThis number should not increase any more with the corona virus.\n\n#COVID19InTurkeysPrisons', 'hashtags': ['COVID19InTurkeysPrisons'], 'user': {'user_id': 1246430262940045314, 'name': 'Yenibahar', 'screen_name': 'Yenibahar21'}, 'retweet_count': 27, 'favorite_count': 19, 'created_at': datetime.datetime(2020, 4, 12, 18, 47, 11)}]}], Timestamp: 1713929298.754107, Age: 5.05 seconds

# %%
# Fetching top 10 users based on followers count
top_users = top_10_users()
print("\nTop 10 Users:")
for user in top_users:
    pprint(user)
# Out:
# Top 10 Users:
# {'created_at': datetime.datetime(2009, 8, 27, 3, 3, 5),
#  'followers_count': 15884929,
#  'friends_count': 28,
#  'location': 'Jakarta, Indonesia',
#  'name': 'detikcom',
#  'screen_name': 'detikcom',
#  'statuses_count': 1631924,
#  'user_id': 69183155}
# {'created_at': datetime.datetime(2009, 8, 3, 13, 23, 45),
#  'followers_count': 14608046,
#  'friends_count': 721,
#  'location': 'Scotland',
#  'name': 'J.K. Rowling',
#  'screen_name': 'jk_rowling',
#  'statuses_count': 12592,
#  'user_id': 62513246}
# {'created_at': datetime.datetime(2009, 5, 26, 11, 31),
#  'followers_count': 9704885,
#  'friends_count': 416,
#  'location': 'India',
#  'name': 'AajTak',
#  'screen_name': 'aajtak',
#  'statuses_count': 398484,
#  'user_id': 42606652}
# {'created_at': datetime.datetime(2009, 5, 11, 12, 25, 51),
#  'followers_count': 9562582,
#  'friends_count': 248,
#  'location': 'India',
#  'name': 'ABP News',
#  'screen_name': 'ABPNews',
#  'statuses_count': 236879,
#  'user_id': 39240673}
# {'created_at': datetime.datetime(2011, 1, 20, 12, 17, 23),
#  'followers_count': 9499328,
#  'friends_count': 391,
#  'location': 'India',
#  'name': 'TIMES NOW',
#  'screen_name': 'TimesNow',
#  'statuses_count': 511529,
#  'user_id': 240649814}
# {'created_at': datetime.datetime(2009, 7, 13, 6, 14, 44),
#  'followers_count': 8947342,
#  'friends_count': 568,
#  'location': 'New Delhi',
#  'name': 'Rajdeep Sardesai',
#  'screen_name': 'sardesairajdeep',
#  'statuses_count': 63226,
#  'user_id': 56304605}
# {'created_at': datetime.datetime(2009, 3, 16, 18, 44, 51),
#  'followers_count': 8808784,
#  'friends_count': 628,
#  'location': 'Paris',
#  'name': 'Le Monde',
#  'screen_name': 'lemondefr',
#  'statuses_count': 330294,
#  'user_id': 24744541}
# {'created_at': datetime.datetime(2009, 7, 10, 8, 16, 35),
#  'followers_count': 8787649,
#  'friends_count': 50,
#  'location': 'Indonesia',
#  'name': 'tvOneNews',
#  'screen_name': 'tvOneNews',
#  'statuses_count': 204242,
#  'user_id': 55507370}
# {'created_at': datetime.datetime(2009, 3, 8, 19, 32, 4),
#  'followers_count': 7678178,
#  'friends_count': 23,
#  'location': 'Indonesia',
#  'name': 'Kompas.com',
#  'screen_name': 'kompascom',
#  'statuses_count': 1522866,
#  'user_id': 23343960}
# {'created_at': datetime.datetime(2008, 6, 5, 10, 5, 7),
#  'followers_count': 7429223,
#  'friends_count': 29,
#  'location': 'Turkey',
#  'name': 'NTV',
#  'screen_name': 'ntv',
#  'statuses_count': 244247,
#  'user_id': 15016209}

# %%
# Fetching top 10 tweets based on favorite count
top_tweets = top_10_tweets()
print("\nTop 10 Tweets:")
for tweet in top_tweets:
    pprint(tweet)
# Out:
# Top 10 Tweets:
# {'_id': ObjectId('66284eae57e2ad708cc1c432'),
#  'favorite_count': 1128502,
#  'text': 'ALERT‼️‼️‼️\n'
#          'The corona virus can be spread through money. If you have any money '
#          'at home, put on some gloves, put all the money in to a plastic bag '
#          "and put it outside the front door tonight. I'm collecting all the "
#          'plastic bags tonight for safety. Think of your health.',
#  'tweet_id': 1249408877554270208}
# {'_id': ObjectId('66285a0257e2ad708cc26875'),
#  'favorite_count': 811062,
#  'text': '*corona virus enters my body*\n'
#          '\n'
#          'The 4 Flintstone gummies I ate in 2005: https://t.co/3STfdIQtaT',
#  'tweet_id': 1254038604927643653}
# {'_id': ObjectId('6628593d57e2ad708cc25d55'),
#  'favorite_count': 764405,
#  'text': 'When this Corona shit passes we have to promise each other that '
#          'we’re going to tell our kids that we survived a zombie apocalypse in '
#          '2020',
#  'tweet_id': 1254037586265411584}
# {'_id': ObjectId('6628577b57e2ad708cc243bc'),
#  'favorite_count': 764405,
#  'text': 'When this Corona shit passes we have to promise each other that '
#          'we’re going to tell our kids that we survived a zombie apocalypse in '
#          '2020',
#  'tweet_id': 1254035181465481217}
# {'_id': ObjectId('66284da257e2ad708cc1b502'),
#  'favorite_count': 598511,
#  'text': 'If I gave you 100 skittles and told you 3 of them could kill you.... '
#          'I’m sure you would avoid the fucking skittles',
#  'tweet_id': 1249407754286051328}
# {'_id': ObjectId('66284e3957e2ad708cc1bd85'),
#  'favorite_count': 598342,
#  'text': 'If I gave you 100 skittles and told you 3 of them could kill you.... '
#          'I’m sure you would avoid the fucking skittles '
#          'https://t.co/VOqOdq4C9d',
#  'tweet_id': 1249408387709722624}
# {'_id': ObjectId('66284de157e2ad708cc1b898'),
#  'favorite_count': 598341,
#  'text': 'If I gave you 100 skittles and told you 3 of them could kill you.... '
#          'I’m sure you would avoid the fucking skittles '
#          'https://t.co/VOqOdq4C9d',
#  'tweet_id': 1249408019416281088}
# {'_id': ObjectId('66284e7a57e2ad708cc1c141'),
#  'favorite_count': 572346,
#  'text': 'It wasn’t no corona till y’all started balancing brooms in the '
#          'house, y’all let the devil in',
#  'tweet_id': 1249408657613377536}
# {'_id': ObjectId('66284dd457e2ad708cc1b7dd'),
#  'favorite_count': 572345,
#  'text': 'It wasn’t no corona till y’all started balancing brooms in the '
#          'house, y’all let the devil in',
#  'tweet_id': 1249407966350061570}
# {'_id': ObjectId('66284a7357e2ad708cc186c3'),
#  'favorite_count': 517027,
#  'text': 'THIS MAN IS A GENIUS he figured out the Corona virus problem 😮 '
#          'https://t.co/EZP7IqTtxV',
#  'tweet_id': 1249404524332269568}

# %%
# Example search by text for "India" - first call
first_search_results_india = perform_search(
    query_type='text', 
    query='India', 
    page=1, 
    per_page=10
)
print("First Search Results for 'India':")
print(first_search_results_india)

# Example search by text for "India" - second call, expecting a cache hit
second_search_results_india = perform_search(
    query_type='text', 
    query='India', 
    page=1, 
    per_page=10
)
print("\nSecond Search Results for 'India' (should be from cache):")
print(second_search_results_india)
# Out:
# Cache miss for India
# Search completed in 0.64 seconds
# First Search Results for 'India':
# [{'_id': ObjectId('66284b6957e2ad708cc194c5'), 'tweet_id': 1249405547129925632, 'text': 'When Corona Virus  is over, let’s spend our holidays in India, eat in local restaurants, buy local meats and veggies , buy clothes and shoes from indian brands and support local businesses. These businesses are going to find it very difficult to survive without our help.', 'hashtags': [], 'user': {'user_id': 164932759, 'name': 'Raj jha', 'screen_name': 'Rajjha07'}, 'retweet_count': 21125, 'favorite_count': 92954, 'created_at': datetime.datetime(2020, 4, 12, 18, 34, 29)}, {'_id': ObjectId('66285f0757e2ad708cc2b13b'), 'tweet_id': 1254045330556940288, 'text': 'Namaste india 🙏 hum sab corona virus ko harane mein ek saath hai , hum sab apne apne sarkar ki baat ka nirdes kare aur ghar me kuch Dino ke liye rahe , yeh samay hai hosiyaar rahene ka .App sabhi ko der sara pyaar 💕\n\nMy Hindi teacher - @shreevats1 🙏🏻', 'hashtags': [], 'user': {'user_id': 1252106780223537155, 'name': 'Razafatima2008@gmail.com', 'screen_name': 'razafatima2008'}, 'retweet_count': 17064, 'favorite_count': 91575, 'created_at': datetime.datetime(2020, 4, 25, 13, 51, 20)}, {'_id': ObjectId('662860d857e2ad708cc2cb9c'), 'tweet_id': 1254047691165712384, 'text': 'The Govt announcement today of a financial assistance package, is the first step in the right direction. India owes a debt to its farmers, daily wage earners, labourers, women &amp; the elderly who are bearing the brunt of the ongoing lockdown.\n\n#Corona', 'hashtags': ['Corona'], 'user': {'user_id': 3240124281, 'name': 'Irfan Madni', 'screen_name': 'IrfanMadniMP'}, 'retweet_count': 14083, 'favorite_count': 83004, 'created_at': datetime.datetime(2020, 4, 25, 14, 0, 43)}, {'_id': ObjectId('6628555857e2ad708cc2247e'), 'tweet_id': 1254032253027573766, 'text': 'Excellent way to use the power of the media to spread a message of hope and positivity...that India will defeat COVID-19. \n\nWell done team @CNNnews18! #JantaCurfew', 'hashtags': ['JantaCurfew'], 'user': {'user_id': 1038609722973114368, 'name': 'ASHISH JI RAJPUT🇮🇳🇮🇳', 'screen_name': 'mmmm57093994'}, 'retweet_count': 4284, 'favorite_count': 25268, 'created_at': datetime.datetime(2020, 4, 25, 12, 59, 22)}, {'_id': ObjectId('66284deb57e2ad708cc1b924'), 'tweet_id': 1249408056670081026, 'text': 'Hey @rahulkanwal I live in a student housing complex in Germany. When the Covid-19 lockdown came almost everyone decided to stay put. It\'s mostly students from India, Pakistan, China on my floor w/ shared bathrooms and kitchen but German media isn\'t calling us "Corona hotspots"', 'hashtags': [], 'user': {'user_id': 1207231798217805824, 'name': 'Shajar Bin Tauhidi شجر بن توحيدى\u200e', 'screen_name': 'ShajarBin'}, 'retweet_count': 6844, 'favorite_count': 22402, 'created_at': datetime.datetime(2020, 4, 12, 18, 44, 28)}, {'_id': ObjectId('66284cf957e2ad708cc1ab79'), 'tweet_id': 1249407081360179200, 'text': 'Hey @rahulkanwal I live in a student housing complex in Germany. When the Covid-19 lockdown came almost everyone decided to stay put. It\'s mostly students from India, Pakistan, China on my floor w/ shared bathrooms and kitchen but German media isn\'t calling us "Corona hotspots"', 'hashtags': [], 'user': {'user_id': 1125394844841418752, 'name': 'alwayslearner', 'screen_name': 'always1earner'}, 'retweet_count': 6843, 'favorite_count': 22398, 'created_at': datetime.datetime(2020, 4, 12, 18, 40, 35)}, {'_id': ObjectId('66284b2857e2ad708cc1911d'), 'tweet_id': 1249405296033689600, 'text': 'Hey @rahulkanwal I live in a student housing complex in Germany. When the Covid-19 lockdown came almost everyone decided to stay put. It\'s mostly students from India, Pakistan, China on my floor w/ shared bathrooms and kitchen but German media isn\'t calling us "Corona hotspots"', 'hashtags': [], 'user': {'user_id': 2388630906, 'name': 'Javed Hussain', 'screen_name': 'javed_Hussain9'}, 'retweet_count': 6843, 'favorite_count': 22392, 'created_at': datetime.datetime(2020, 4, 12, 18, 33, 30)}, {'_i ...
# Cache hit for India, fetched in 0.00 seconds
#
# Second Search Results for 'India' (should be from cache):
# [{'_id': ObjectId('66284b6957e2ad708cc194c5'), 'tweet_id': 1249405547129925632, 'text': 'When Corona Virus  is over, let’s spend our holidays in India, eat in local restaurants, buy local meats and veggies , buy clothes and shoes from indian brands and support local businesses. These businesses are going to find it very difficult to survive without our help.', 'hashtags': [], 'user': {'user_id': 164932759, 'name': 'Raj jha', 'screen_name': 'Rajjha07'}, 'retweet_count': 21125, 'favorite_count': 92954, 'created_at': datetime.datetime(2020, 4, 12, 18, 34, 29)}, {'_id': ObjectId('66285f0757e2ad708cc2b13b'), 'tweet_id': 1254045330556940288, 'text': 'Namaste india 🙏 hum sab corona virus ko harane mein ek saath hai , hum sab apne apne sarkar ki baat ka nirdes kare aur ghar me kuch Dino ke liye rahe , yeh samay hai hosiyaar rahene ka .App sabhi ko der sara pyaar 💕\n\nMy Hindi teacher - @shreevats1 🙏🏻', 'hashtags': [], 'user': {'user_id': 1252106780223537155, 'name': 'Razafatima2008@gmail.com', 'screen_name': 'razafatima2008'}, 'retweet_count': 17064, 'favorite_count': 91575, 'created_at': datetime.datetime(2020, 4, 25, 13, 51, 20)}, {'_id': ObjectId('662860d857e2ad708cc2cb9c'), 'tweet_id': 1254047691165712384, 'text': 'The Govt announcement today of a financial assistance package, is the first step in the right direction. India owes a debt to its farmers, daily wage earners, labourers, women &amp; the elderly who are bearing the brunt of the ongoing lockdown.\n\n#Corona', 'hashtags': ['Corona'], 'user': {'user_id': 3240124281, 'name': 'Irfan Madni', 'screen_name': 'IrfanMadniMP'}, 'retweet_count': 14083, 'favorite_count': 83004, 'created_at': datetime.datetime(2020, 4, 25, 14, 0, 43)}, {'_id': ObjectId('6628555857e2ad708cc2247e'), 'tweet_id': 1254032253027573766, 'text': 'Excellent way to use the power of the media to spread a message of hope and positivity...that India will defeat COVID-19. \n\nWell done team @CNNnews18! #JantaCurfew', 'hashtags': ['JantaCurfew'], 'user': {'user_id': 1038609722973114368, 'name': 'ASHISH JI RAJPUT🇮🇳🇮🇳', 'screen_name': 'mmmm57093994'}, 'retweet_count': 4284, 'favorite_count': 25268, 'created_at': datetime.datetime(2020, 4, 25, 12, 59, 22)}, {'_id': ObjectId('66284deb57e2ad708cc1b924'), 'tweet_id': 1249408056670081026, 'text': 'Hey @rahulkanwal I live in a student housing complex in Germany. When the Covid-19 lockdown came almost everyone decided to stay put. It\'s mostly students from India, Pakistan, China on my floor w/ shared bathrooms and kitchen but German media isn\'t calling us "Corona hotspots"', 'hashtags': [], 'user': {'user_id': 1207231798217805824, 'name': 'Shajar Bin Tauhidi شجر بن توحيدى\u200e', 'screen_name': 'ShajarBin'}, 'retweet_count': 6844, 'favorite_count': 22402, 'created_at': datetime.datetime(2020, 4, 12, 18, 44, 28)}, {'_id': ObjectId('66284cf957e2ad708cc1ab79'), 'tweet_id': 1249407081360179200, 'text': 'Hey @rahulkanwal I live in a student housing complex in Germany. When the Covid-19 lockdown came almost everyone decided to stay put. It\'s mostly students from India, Pakistan, China on my floor w/ shared bathrooms and kitchen but German media isn\'t calling us "Corona hotspots"', 'hashtags': [], 'user': {'user_id': 1125394844841418752, 'name': 'alwayslearner', 'screen_name': 'always1earner'}, 'retweet_count': 6843, 'favorite_count': 22398, 'created_at': datetime.datetime(2020, 4, 12, 18, 40, 35)}, {'_id': ObjectId('66284b2857e2ad708cc1911d'), 'tweet_id': 1249405296033689600, 'text': 'Hey @rahulkanwal I live in a student housing complex in Germany. When the Covid-19 lockdown came almost everyone decided to stay put. It\'s mostly students from India, Pakistan, China on my floor w/ shared bathrooms and kitchen but German media isn\'t calling us "Corona hotspots"', 'hashtags': [], 'user': {'user_id': 2388630906, 'name': 'Javed Hussain', 'screen_name': 'javed_Hussain9'}, 'retweet_count': 6843, 'favorite_count': 22392, 'created_at': datetime.datetime(2020, 4, 12, 18, 33, 30)}, {'_i ...

# %%
cache.persist()
